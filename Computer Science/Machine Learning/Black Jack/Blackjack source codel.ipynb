# %% [markdown]
# # BlackJack : Monte-Carlo with Exploring Start
# ----
#
# ## 설명
# 블랙잭 게임에서의 최적 Policy를 찾는 프로그램입니다. 본 프로그램에서 정의된 블랙잭 룰은 다음과 같습니다.
#  - 하나의 카드 덱(조커를 제외한 52장의 카드)을 사용
#  - 카드의 합을 계산할 시 A = 1 or 11, J,Q,K = 10으로 계산
#  - 플레이어는 Hit 또는 Stick만을 할 수 있음
#  - 카드의 합이 21 이하일 경우, 딜러와 플레이어 중 숫자가 더 높은 쪽이 승리.
#  - 카드의 합이 21 초과한 딜러/플레이어는 패배
#  - 카드의 합이 같을 경우 무승부
#
# 본 프로그램에서는 최적 Policy를 찾기 위해 Monte-Carlo Control with Exploring Start[1] 알고리즘을 사용합니다. 최적 Policy를 찾기 위해, 본 프로그램은 다음과 같은 변수로 구성된 State로부터 탐색을 수행합니다.
#  - 플레이어 카드의 합 : 12 ~ 21 사이의 정수
#  - 딜러가 보여주는 카드의 숫자 : 1 ~ 10 사이의 정수
#  - 플레이어가 현재 사용 가능한 Ace의 유무 : True / False
#
# 위와 같이 구성된 State S에서 Action A를 선택했을 때의 기대 리턴(게임이 끝났을 때 얻을 것으로 기대되는 보상의 합)은 Q(S,A)입니다. 많은 에피소드를 경험할수혹 Agent는 Optimal Q(S,A)에 가까운 값을 학습하게 되며, 이로부터 최적 Policy를 찾을 수 있습니다.
#
# ----
#
# ## 0. Package
# 먼저 본 프로그램에서 사용할 Package를 Import합니다.

# %%
# %matplotlib inline
import random
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors

# %% [markdown]
# ## 1. Class : Deck
# 카드 덱 한 벌에 해당하는 클래스를 선언합니다. 조커를 제외한 52장의 카드로 이루어져 있으며, 각 카드는 정수로 표기됩니다. <br>
# A = 11, J, Q, K = 10으로 표현되며, 나머지 카드는 해당 카드에 적힌 숫자만큼의 값을 갖습니다.
#
# ### 클래스 구성
# * Attributes
#    * card_deck : List, 52개의 정수로 이루어짐
# * Methods
#    * shuffle() : 카드 덱을 랜덤하게 섞음
#    * draw() : 카드 덱에서 한 장을 뽑아 리턴
#    * reset() : 카드 덱을 초기화함

# %%
class Deck(object):
    """
    Deck : Card deck, which can be shuffled, drawn, and reset.
    """

    def __init__(self):
        deck = [2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10, 11]
        self.card_deck = deck * 4
        self.shuffle()

    def shuffle(self):
        random.shuffle(self.card_deck)

    def draw(self):
        return self.card_deck.pop()

    def reset(self):
        deck = [2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10, 11]
        self.card_deck = deck * 4
        self.shuffle()

# %% [markdown]
# ## 2. Class : Dealer
# 다음으로 Dealer 클래스를 선언합니다.<br>
# Dealer 클래스는 강화학습에서의 Environment에 해당합니다. 플레이어의 Action을 받고, 그에 따른 다음 State와 Reward를 반환합니다.<br>
# 딜러는 시작할 때 두 장의 카드를 받습니다. 플레이어의 차례가 끝난 후, 플레이어의 카드 합이 21을 넘지 않는다면 딜러는 다음과 같이 행동합니다.
#  - 딜러 카드의 합이 17 미만일 때 : 카드 한 장을 추가로 뽑음 (Hit)
#  - 딜러 카드의 합이 17 이상일 때 : 플레이어의 카드 합과 비교하여 승패 결정 (Stick)
#
# ### 클래스 구성
# 딜러 클래스는 다음과 같이 구성됩니다
#  - Attributes
#      - hands : List, 딜러가 가지고 있는 카드들
#      - usable_ace : List, 딜러가 가지고 있는 A의 인덱스
#  - Methods
#      - hit(deck) : 카드 덱에서 카드 한 장을 뽑아 hands에 추가
#      - show() : 딜러가 가진 카드 중 랜덤한 한 장의 값을 리턴
#      - calculate_sum() : 딜러가 가진 카드의 합을 리턴. 카드 합이 21 이상일 때 사용 가능한 Ace가 있다면 사용함.
#      - action() : 딜러의 Action - 합이 17 미만이면 hit, 이상이면 stick
#      - observation(action, agent, deck) : 플레이어의 action을 받아 종료 여부와 reward 리턴
#      - calculate_rewards(agent, deck) : 플레이어와 딜러의 승패 계산 및 reward 리턴
#      - reset() : 딜러 클래스의 모든 attribute 초기화

# %%
class Dealer(object):
    """
    Dealer : 딜러 클래스
    딜러는 두 장의 카드를 받고, 카드의 합이 16 이하이면 Hit, 17이상이면 Stick 함.
    처음 두 장을 받았을 때 한 장의 카드를 랜덤하게 오픈함.
    """

    def __init__(self):
        """
        hand : 딜러가 가진 카드
        usable_ace : 딜러가 가진 카드 리스트 중 ace의 인덱스
        natural : 두 장의 카드로 21이 되면 True, 아니면 False
        """
        self.hands = list()
        self.usable_ace = list()

    def hit(self, deck: Deck):
        """
        딜러의 Hit. 새로운 카드가 Ace라면 사용 가능한 Ace 리스트에 추가함
        :param deck: Deck Object
        :return:
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)

    def show(self):
        """
        딜러가 가진 카드 중 하나를 랜덤하게 보여줌
        :return: 딜러의 카드 중 랜덤한 카드 숫자
        """
        card = random.choice(self.hands)
        if card == 11:
            card = 1
        return card

    def calculate_sum(self):
        """
        딜러가 가진 카드의 합을 구함
        21을 넘을 때 사용 가능한 Ace가 있으면 사용함
        :return: 딜러 카드의 합
        """
        sums = sum(self.hands)
        if sums > 21 and len(self.usable_ace) > 0:
            self.hands[self.usable_ace.pop()] = 1
            sums = sum(self.hands)
        return sums

    def action(self, deck: Deck):
        """
        딜러의 순서 때 딜러의 행동.
        숫자의 합이 16 이하일 때는 Hit, 17 이상이면 Stick
        :param deck:
        :return:
        """
        while True:
            sums = self.calculate_sum()
            if sums < 17:
                self.hit(deck)
            else:
                return sums

    def observation(self, action, agent, deck):
        """
        플레이어의 Action을 받아, 그에 맞는 Observation과 Reward를 반환
        :param action: agent 의 Action
        :param agent: agent 클래스
        :param deck: deck 클래스
        :return: 에피소드 종료 여부, reward
        """
        done = False
        reward = 0
        if action == True:  # Hit
            agent.hit(deck)
            if agent.calculate_sum() > 21:  #플레이어의 Hit으로 인해 카드 합이 21이 넘으면 즉시 종료
                done = True
                reward = -1
        else:  # Stick
            done = True
            reward = self.calcuate_reward(agent, deck)

        return done, reward

    def calcuate_reward(self, agent, deck):
        """
        플레이어가 Stick했을 때 딜러와의 카드 비교 수행
        :param agent:
        :param deck:
        :return: Reward
        """
        agent_sum = agent.calculate_sum()           # 플레이어의 카드 합 계산
        if agent_sum > 21:                          # 플레이어의 Bust (패)
            return -1

        dealer_sum = self.action(deck)              # 딜러의 카드 합 계산
        if dealer_sum > 21:                         # 딜러가 Bust (승)
            return 1
        if dealer_sum > agent_sum:                  # 딜러의 카드 합 > 플레이어 합 (패)
            return -1
        if dealer_sum < agent_sum:                  # 딜러의 카드 합 < 플레이어 합 (승)
            return 1
        return 0                                   # 딜러의 카드 합 == 플레이어의 합 (무)

    def reset(self):
        """
        딜러 초기화 (새로운 에피소드 시작을 위해)
        """
        self.hands = list()
        self.usable_ace = list()

# %% [markdown]
# ## 3. Class : Agent
# Agent 클래스는 플레이어에 해당하며, 최적 Policy를 학습하는 주체가 됩니다. Agent는 여러 에피소드들로부터 Q값(기대 Return)을 계산하고, 다음 에피소드 수행 시 해당 State에서 Q값이 높은 Action을 선택하는 Greedy Policy를 따릅니다.
#
# ### 클래스 구성
#
# Agent의 구성은 다음과 같습니다.
#
#  - Attributes
#      - hands : List, Agent가 가지고 있는 카드들
#      - usable_ace : List, Agent가 가지고 있는 A의 인덱스
#      - Q_table : Dictionary, 기대 Return값과 방문 횟수를 저장
#  - Methods
#      - hit(deck) : 카드 덱에서 카드 한 장을 뽑아 hands에 추가
#      - calculate_sum() : Agent가 가진 카드의 합을 리턴. 카드 합이 21 이상일 때 사용 가능한 Ace가 있다면 사용함.
#      - random_action() : 현재 State에 상관없이 랜덤하게 Action을 리턴
#      - policy(state) : 현재 State에서 가능한 Action 중, Q_table의 값이 큰 Action을 리턴
#      - update_qval(episode) : 에피소드로부터 평균 리턴을 계산하여 Q_table을 업데이트
#      - reset() : Agent 클래스의 모든 attribute 초기화

# %%
class Agent(object):
    def __init__(self):
        """
        hand : 플레이어의 카드
        usable_ace : 사용 가능한 ace 리스트
        Q_table : q(s,a) 값을 저장할 딕셔너리
        """
        self.hands = list()
        self.usable_ace = list()
        self.Q_table = dict()

    def hit(self, deck: Deck):
        """
        덱에서 새로운 카드를 뽑음
        :param deck: Deck for draw a card
        :return: None
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)

    def calculate_sum(self):
        """
        플레이어가 가진 카드의 합을 구함.
        21을 넘을 때 사용 가능한 ace가 있으면 사용함
        :return:
        """
        sums = sum(self.hands)
        if sums > 21 and len(self.usable_ace) > 0:
            self.hands[self.usable_ace.pop()] = 1
            sums = sum(self.hands)
        return sums

    def random_action(self):
        """
        랜덤하게 행동
        True = hit, False = stick
        :return:
        """
        return random.choice([True, False])

    def policy(self, state):
        """
        Agent의 policy 함수.
        e의 확률로 랜덤 행동을 하며, 그 외에는 현재 state에서 큰 q(s,a)값을 갖는 action을 선택함
        :param state: Agent에게 주어진 state
        :return: agent의 action을 반환 , True = hit and False = stick
        """
        # Q_table에서 현재 state-action에 대해 값이 존재하는지 검사함
        for action in (True, False):
            if (state, action) not in self.Q_table.keys():  # Q_table에 값이 없으면 0으로 초기화
                self.Q_table[(state, action)] = [0, 0]      # (mean return, visit count)
            else:
                continue

        # q값이 큰 action 선택
        if self.Q_table[(state, True)] > self.Q_table[(state, False)]:
            return True     # Hit
        elif self.Q_table[(state, True)] == self.Q_table[(state, False)]:   # q값이 같으면 무작위추출
            return self.random_action()
        else:
            return False    # Stick


    def reset(self):
        """
        Agent를 리셋함
        :return: None
        """
        self.hands = list()
        self.usable_ace = list()

    def update_qval(self, episode):
        """
        에피소드(한 번의 게임)으로부터 Q_table 을 업데이트함
        Q 테이블에 없는 state-action 쌍이 나오면 새로 생성
        Q 테이블에 state-action 쌍이 존재한다면 Incremental mean 적용하여 업데이트
        :param episode: Episode generated from environment
        :return: None
        """
        total_return = 0
        for state, action, reward in episode[::-1]:     # 에피소드의 뒤에서부터 (역순)
            total_return += reward                       # return Gt 계산
            if (state, action) not in self.Q_table.keys():  # state-action 쌍이 없다면
                self.Q_table[(state, action)] = [total_return, 1]   # 새롭게 엔트리 생성 (Gt, count)

            else:  #이미 존재하는 state-action 쌍이면 Incremental mean 적용
                prev_val = self.Q_table[(state, action)][0]         # 이전의 평균 return
                count = self.Q_table[(state, action)][1] + 1        # count 증가
                mean = prev_val + (total_return - prev_val) / count # 평균 계산 : Incremental Mean 적용
                self.Q_table[(state, action)] = [mean, count]  # 업데이트

# %% [markdown]
# ## 4. Class : MonteCarlo
# Monte-Carlo control with Exploring Start를 구현한 클래스입니다. 에피소드를 생성할 수 있고, 생성된 에피소드로부터 에이전트를 학습시킵니다.
# 에피소드 생성 시 Exploring Start를 위해 에피소드의 첫 번째 State에서는 무작위로 Action을 선택하며, 이후에는 에이전트의 Policy를 따라 Action을 선택합니다.
#
# ### 클래스 구성
# MonteCarlo 클래스는 다음과 같이 구성됩니다.
#  - Attribute
#      - 없음
#  - Methods
#      - generate_episode(dealer, agent, deck) : 딜러, 플레이어, 카드 덱을 이용해 한 번의 블랙잭 게임을 진행하고 에피소드를 반환합니다.
#      - train(dealer, agent, deck, it, verbose) : 지정된 이터레이션 수만큼의 에피소드로부터 플레이어를 학습시킵니다.

# %%
class MonteCarlo(object):
    def generate_episode(self, dealer: Dealer, agent: Agent, deck: Deck):
        """
        하나의 에피소드(게임)를 생성함
        :param dealer:
        :param agent:
        :param deck:
        :return:
        """
        
        # 카드 덱, 딜러, Agent를 초기화
        deck.reset()
        dealer.reset()
        agent.reset()
        agent.hit(deck)
        agent.hit(deck)
        dealer.hit(deck)
        dealer.hit(deck)

        done = False    # 에피소드의 종료 여부

        episode = list()    # 에피소드

        while not done:
            # 에피소드가 끝날 때까지 State, Action, Reward를 생성
            sums = agent.calculate_sum()
            if sums < 12:
                agent.hit(deck)
                continue

            state = (sums, bool(agent.usable_ace), dealer.show())

            ########   Exploring Start ~!!!!!!!!! : 
            if len(episode) == 0:       # 첫번째 State 일 때는 무작위 Action 선택
                action =agent.random_action()
            else:                       # 그 외에는 Q 테이블에서 큰 값을 갖는 Action 선택
                action = agent.policy(state)
            
            done, reward = dealer.observation(action, agent, deck)  # 에피소드 종료 여부, Reward 계산
            
            # 생성된 State, Action, Reward를 에피소드에 추가
            episode.append([state, action, reward])

        return episode

    def train(self, dealer: Dealer, agent: Agent, deck: Deck, it=10000, verbose=True):
        count = 0
        win = 0
        loss = 0
        draw = 0
        total_win = 0
        total_loss = 0
        total_draw = 0
        result = str()
        for i in range(it):
            count += 1
            episode = self.generate_episode(dealer, agent, deck)
            agent.update_qval(episode)

            if episode[-1][-1] == 1:
                win += 1
            elif episode[-1][-1] == 0:
                draw += 1
            else:
                loss += 1

            if count % 1000 == 0 and verbose == True:
                total_win += win
                total_loss += loss
                total_draw += draw

                print("========== Training : Episode ", count, " ===========")
                print("Recent 1000 games win rate :{:.3f}%".format(win / (win + loss) * 100))
                print(" -- 1000 Games WIN :", win, "DRAW :", draw, "LOSS :", loss)
                print("Total win rate : {:.3f}%".format(total_win / (total_win + total_loss) * 100))
                print(" -- TOTAL Games WIN :", total_win, "DRAW :", total_draw, "LOSS :", total_loss)

                win = 0
                loss = 0
                draw = 0

# %% [markdown]
# ## 5. Function : plot_q_val(agent, usable_ace)
# Q값을 시각화하기 위한 함수입니다.

# %%
def plot_q_val(agent: Agent, usable_ace=True):
    fig = plt.figure()
    ax = Axes3D(fig)

    hands = set()
    dealer_show = set()

    for state, action in sorted(agent.Q_table.keys()):
        hands.add(state[0])
        dealer_show.add(state[2])

    Z_list = list()

    l = list()

    for d in dealer_show:
        l = []
        for hand in hands:
            if ((hand, usable_ace, d), True) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), True)] = [0, 0]
            if ((hand, usable_ace, d), False) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), False)] = [0, 0]
            v_val = max([agent.Q_table[((hand, usable_ace, d), True)][0], agent.Q_table[((hand, usable_ace, d), False)][0]])
            l.append(v_val)
        Z_list.append(l)

    Y = np.array(list(hands))
    X = np.array(list(dealer_show))
    if usable_ace:
        X, Y = np.meshgrid(X, Y)
    else:
        X, Y = np.meshgrid(X, Y)

    Z = np.array(Z_list).T

    ax.plot_wireframe(X, Y, Z)
    plt.show()

# %% [markdown]
# ## 6. Function : plot_q_val(agent, usable_ace)
# 최적 Policy를 시각화하기 위한 함수입니다.

# %%
def plot_action(agent: Agent, usable_ace=True):
    hands = set()
    dealer_show = set()

    for state, action in sorted(agent.Q_table.keys()):
        hands.add(state[0])
        dealer_show.add(state[2])

    Z_list = list()

    l = list()

    action = False

    for d in dealer_show:
        l = []
        for hand in hands:
            if ((hand, usable_ace, d), True) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), True)] = [0, 0]
            if ((hand, usable_ace, d), False) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), False)] = [0, 0]
            l.append(0 if agent.Q_table[((hand, usable_ace, d), True)][0] > agent.Q_table[((hand, usable_ace, d), False)][0] else 1)
        Z_list.append(l)

    Y = np.array(list(hands))
    X = np.array(list(dealer_show))
    if usable_ace:
        X, Y = np.meshgrid(X, Y)
    else:
        X, Y = np.meshgrid(X, Y)
    Z = np.array(Z_list).T

    data = Z[::-1,:]
    data = np.append(data, [0 for _ in range(Z[0].shape[0])]).reshape(-1,Z[0].shape[0])
    
    cmap=cm.coolwarm
    plt.imshow(data, cmap=cmap, extent=[1,11,11,21])

    plt.show()
    return X, Y, Z

# %% [markdown]
# ## 7. 최적 Policy 학습

# %%
deck = Deck()
dealer = Dealer()
agent = Agent()
mc_es = MonteCarlo()

mc_es.train(dealer, agent, deck, it=1000000)
# Out:
# ========== Training : Episode  1000  ===========
# Recent 1000 games win rate :35.362%
#  -- 1000 Games WIN : 337 DRAW : 47 LOSS : 616
# Total win rate : 35.362%
#  -- TOTAL Games WIN : 337 DRAW : 47 LOSS : 616
# ========== Training : Episode  2000  ===========
# Recent 1000 games win rate :36.724%
#  -- 1000 Games WIN : 343 DRAW : 66 LOSS : 591
# Total win rate : 36.036%
#  -- TOTAL Games WIN : 680 DRAW : 113 LOSS : 1207
# ========== Training : Episode  3000  ===========
# Recent 1000 games win rate :35.895%
#  -- 1000 Games WIN : 341 DRAW : 50 LOSS : 609
# Total win rate : 35.989%
#  -- TOTAL Games WIN : 1021 DRAW : 163 LOSS : 1816
# ========== Training : Episode  4000  ===========
# Recent 1000 games win rate :33.653%
#  -- 1000 Games WIN : 316 DRAW : 61 LOSS : 623
# Total win rate : 35.408%
#  -- TOTAL Games WIN : 1337 DRAW : 224 LOSS : 2439
# ========== Training : Episode  5000  ===========
# Recent 1000 games win rate :36.220%
#  -- 1000 Games WIN : 343 DRAW : 53 LOSS : 604
# Total win rate : 35.571%
#  -- TOTAL Games WIN : 1680 DRAW : 277 LOSS : 3043
# ========== Training : Episode  6000  ===========
# Recent 1000 games win rate :33.263%
#  -- 1000 Games WIN : 316 DRAW : 50 LOSS : 634
# Total win rate : 35.184%
#  -- TOTAL Games WIN : 1996 DRAW : 327 LOSS : 3677
# ========== Training : Episode  7000  ===========
# Recent 1000 games win rate :36.943%
#  -- 1000 Games WIN : 348 DRAW : 58 LOSS : 594
# Total win rate : 35.435%
#  -- TOTAL Games WIN : 2344 DRAW : 385 LOSS : 4271
# ========== Training : Episode  8000  ===========
# Recent 1000 games win rate :35.622%
#  -- 1000 Games WIN : 332 DRAW : 68 LOSS : 600
# Total win rate : 35.458%
#  -- TOTAL Games WIN : 2676 DRAW : 453 LOSS : 4871
# ========== Training : Episode  9000  ===========
# Recent 1000 games win rate :36.315%
#  -- 1000 Games WIN : 341 DRAW : 61 LOSS : 598
# Total win rate : 35.553%
#  -- TOTAL Games WIN : 3017 DRAW : 514 LOSS : 5469
# ========== Training : Episode  10000  ===========
# Recent 1000 games win rate :36.803%
#  -- 1000 Games WIN : 343 DRAW : 68 LOSS : 589
# Total win rate : 35.676%
#  -- TOTAL Games WIN : 3360 DRAW : 582 LOSS : 6058
# ========== Training : Episode  11000  ===========
# Recent 1000 games win rate :35.631%
#  -- 1000 Games WIN : 336 DRAW : 57 LOSS : 607
# Total win rate : 35.672%
#  -- TOTAL Games WIN : 3696 DRAW : 639 LOSS : 6665
# ========== Training : Episode  12000  ===========
# Recent 1000 games win rate :35.037%
#  -- 1000 Games WIN : 329 DRAW : 61 LOSS : 610
# Total win rate : 35.619%
#  -- TOTAL Games WIN : 4025 DRAW : 700 LOSS : 7275
# ========== Training : Episode  13000  ===========
# Recent 1000 games win rate :34.984%
#  -- 1000 Games WIN : 332 DRAW : 51 LOSS : 617
# Total win rate : 35.570%
#  -- TOTAL Games WIN : 4357 DRAW : 751 LOSS : 7892
# ========== Training : Episode  14000  ===========
# Recent 1000 games win rate :33.938%
#  -- 1000 Games WIN : 318 DRAW : 63 LOSS : 619
# Total win rate : 35.454%
#  -- TOTAL Games WIN : 4675 DRAW : 814 LOSS : 8511
# ========== Training : Episode  15000  ===========
# Recent 1000 games win rate :33.369%
#  -- 1000 Games WIN : 316 DRAW : 53 LOSS : 631
# Total win rate : 35.315%
#  -- TOTAL Games WIN : 4991 DRAW : 867 LOSS : 9142
# ========== Training : Episode  16000  ===========
# Recent 1000 games win rate :33.688%
#  -- 1000 Games WIN : 317 DRAW : 59 LOSS : 624
# Total win rate : 35.213%
#  -- TOTAL Games WIN : 5308 DRAW : 926 LOSS : 9766
# ========== Training : Episode  17000  ===========
# Recent 1000 games win rate :35.419%
#  -- 1000 Games WIN : 334 DRAW : 57 LOSS : 609
# Total win rate : 35.225%
#  -- TOTAL Games WIN : 5642 DRAW : 983 LOSS : 10375
# ========== Training : Episode  18000  ===========
# Recent 1000 games win rate :32.799%
#  -- 1000 Games WIN : 307 DRAW : 64 LOSS : 629
# Total win rate : 35.091%
#  -- TOTAL Games WIN : 5949 DRAW : 1047 LOSS : 11004
# ========== Training : Episode  19000  ===========
# Recent 1000 games win rate :34.698%
#  -- 1000 Games WIN : 322 DRAW : 72 LOSS : 606
# Total win rate : 35.071%
#  -- TOTAL Games WIN : 6271 DRAW : 1119 LOSS : 11610
# ========== Training : Episode  20000  ===========
# Recent 1000 games win rate :35.515%
#  -- 1000 Games WIN : 331 DRAW : 68 LOSS : 601
# Total win rate : 35.093%
#  -- TOTAL Games WIN : 6602 DRAW : 1187 LOSS : 12211
# ========== Training : Episode  21000  ===========
# Recent 1000 games win rate :35.730%
#  -- 1000 Games WIN : 333 DRAW : 68 LOSS : 599
# Total win rate : 35.123%
#  -- TOTAL Games WIN : 6935 DRAW : 1255 LOSS : 12810
# ========== Training : Episode  22000  ===========
# Recent 1000 games win rate :37.714%
#  -- 1000 Games WIN : 353 DRAW : 64 LOSS : 583
# Total win rate : 35.240%
#  -- TOTAL Games WIN : 7288 DRAW : 1319 LOSS : 13393
# ========== Training : Episode  23000  ===========
# Recent 1000 games win rate :35.575%
#  -- 1000 Games WIN : 328 DRAW : 78 LOSS : 594
# Total win rate : 35.254%
#  -- TOTAL Games WIN : 7616 DRAW : 1397 LOSS : 13987
# ========== Training : Episode  24000  ===========
# Recent 1000 games win rate :35.307%
#  -- 1000 Games WIN : 328 DRAW : 71 LOSS : 601
# Total win rate : 35.257%
#  -- TOTAL Games WIN : 7944 DRAW : 1468 LOSS : 14588
# ========== Training : Episode  25000  ===========
# Recent 1000 games win rate :33.511%
#  -- 1000 Games WIN : 314 DRAW : 63 LOSS : 623
# Total win rate : 35.187%
#  -- TOTAL Games WIN : 8258 DRAW : 1531 LOSS : 15211
# ========== Training : Episode  26000  ===========
# Recent 1000 games win rate :36.910%
#  -- 1000 Games WIN : 344 DRAW : 68 LOSS : 588
# Total win rate : 35.253%
#  -- TOTAL Games WIN : 8602 DRAW : 1599 LOSS : 15799
# ========== Training : Episode  27000  ===========
# Recent 1000 games win rate :33.010%
#  -- 1000 Games WIN : 306 DRAW : 73 LOSS : 621
# Total win rate : 35.171%
#  -- TOTAL Games WIN : 8908 DRAW : 1672 LOSS : 16420
# ========== Training : Episode  28000  ===========
# Recent 1000 games win rate :34.358%
#  -- 1000 Games WIN : 324 DRAW : 57 LOSS : 619
# Total win rate : 35.141%
#  -- TOTAL Games WIN : 9232 DRAW : 1729 LOSS : 17039
# ========== Training : Episode  29000  ===========
# Recent 1000 games win rate :36.383%
#  -- 1000 Games WIN : 342 DRAW : 60 LOSS : 598
# Total win rate : 35.184%
#  -- TOTAL Games WIN : 9574 DRAW : 1789 LOSS : 17637
# ========== Training : Episode  30000  ===========
# Recent 1000 games win rate :34.273%
#  -- 1000 Games WIN : 316 DRAW : 78 LOSS : 606
# Total win rate : 35.154%
#  -- TOTAL Games WIN : 9890 DRAW : 1867 LOSS : 18243
# ========== Training : Episode  31000  ===========
# Recent 1000 games win rate :36.393%
#  -- 1000 Games WIN : 341 DRAW : 63 LOSS : 596
# Total win rate : 35.194%
#  -- TOTAL Games WIN : 10231 DRAW : 1930 LOSS : 18839
# ========== Training : Episode  32000  ===========
# Recent 1000 games win rate :37.580%
#  -- 1000 Games WIN : 351 DRAW : 66 LOSS : 583
# Total win rate : 35.269%
#  -- TOTAL Games WIN : 10582 DRAW : 1996 LOSS : 19422
# ========== Training : Episode  33000  ===========
# Recent 1000 games win rate
# ========== Training : Episode  95000  ===========
# Recent 1000 games win rate :33.936%
#  -- 1000 Games WIN : 319 DRAW : 60 LOSS : 621
# Total win rate : 35.416%
#  -- TOTAL Games WIN : 31569 DRAW : 5863 LOSS : 57568
# ========== Training : Episode  96000  ===========
# Recent 1000 games win rate :35.616%
#  -- 1000 Games WIN : 338 DRAW : 51 LOSS : 611
# Total win rate : 35.418%
#  -- TOTAL Games WIN : 31907 DRAW : 5914 LOSS : 58179
# ========== Training : Episode  97000  ===========
# Recent 1000 games win rate :33.618%
#  -- 1000 Games WIN : 315 DRAW : 63 LOSS : 622
# Total win rate : 35.400%
#  -- TOTAL Games WIN : 32222 DRAW : 5977 LOSS : 58801
# ========== Training : Episode  98000  ===========
# Recent 1000 games win rate :33.652%
#  -- 1000 Games WIN : 317 DRAW : 58 LOSS : 625
# Total win rate : 35.382%
#  -- TOTAL Games WIN : 32539 DRAW : 6035 LOSS : 59426
# ========== Training : Episode  99000  ===========
# Recent 1000 games win rate :33.333%
#  -- 1000 Games WIN : 315 DRAW : 55 LOSS : 630
# Total win rate : 35.361%
#  -- TOTAL Games WIN : 32854 DRAW : 6090 LOSS : 60056
# ========== Training : Episode  100000  ===========
# Recent 1000 games win rate :35.054%
#  -- 1000 Games WIN : 326 DRAW : 70 LOSS : 604
# Total win rate : 35.358%
#  -- TOTAL Games WIN : 33180 DRAW : 6160 LOSS : 60660
# ========== Training : Episode  101000  ===========
# Recent 1000 games win rate :35.487%
#  -- 1000 Games WIN : 335 DRAW : 56 LOSS : 609
# Total win rate : 35.359%
#  -- TOTAL Games WIN : 33515 DRAW : 6216 LOSS : 61269
# ========== Training : Episode  102000  ===========
# Recent 1000 games win rate :35.897%
#  -- 1000 Games WIN : 336 DRAW : 64 LOSS : 600
# Total win rate : 35.365%
#  -- TOTAL Games WIN : 33851 DRAW : 6280 LOSS : 61869
# ========== Training : Episode  103000  ===========
# Recent 1000 games win rate :37.290%
#  -- 1000 Games WIN : 355 DRAW : 48 LOSS : 597
# Total win rate : 35.384%
#  -- TOTAL Games WIN : 34206 DRAW : 6328 LOSS : 62466
# ========== Training : Episode  104000  ===========
# Recent 1000 games win rate :31.974%
#  -- 1000 Games WIN : 298 DRAW : 68 LOSS : 634
# Total win rate : 35.351%
#  -- TOTAL Games WIN : 34504 DRAW : 6396 LOSS : 63100
# ========== Training : Episode  105000  ===========
# Recent 1000 games win rate :34.700%
#  -- 1000 Games WIN : 330 DRAW : 49 LOSS : 621
# Total win rate : 35.345%
#  -- TOTAL Games WIN : 34834 DRAW : 6445 LOSS : 63721
# ========== Training : Episode  106000  ===========
# Recent 1000 games win rate :31.707%
#  -- 1000 Games WIN : 299 DRAW : 57 LOSS : 644
# Total win rate : 35.310%
#  -- TOTAL Games WIN : 35133 DRAW : 6502 LOSS : 64365
# ========== Training : Episode  107000  ===========
# Recent 1000 games win rate :38.723%
#  -- 1000 Games WIN : 364 DRAW : 60 LOSS : 576
# Total win rate : 35.342%
#  -- TOTAL Games WIN : 35497 DRAW : 6562 LOSS : 64941
# ========== Training : Episode  108000  ===========
# Recent 1000 games win rate :36.296%
#  -- 1000 Games WIN : 339 DRAW : 66 LOSS : 595
# Total win rate : 35.351%
#  -- TOTAL Games WIN : 35836 DRAW : 6628 LOSS : 65536
# ========== Training : Episode  109000  ===========
# Recent 1000 games win rate :37.251%
#  -- 1000 Games WIN : 355 DRAW : 47 LOSS : 598
# Total win rate : 35.369%
#  -- TOTAL Games WIN : 36191 DRAW : 6675 LOSS : 66134
# ========== Training : Episode  110000  ===========
# Recent 1000 games win rate :34.847%
#  -- 1000 Games WIN : 330 DRAW : 53 LOSS : 617
# Total win rate : 35.364%
#  -- TOTAL Games WIN : 36521 DRAW : 6728 LOSS : 66751
# ========== Training : Episode  111000  ===========
# Recent 1000 games win rate :35.722%
#  -- 1000 Games WIN : 334 DRAW : 65 LOSS : 601
# Total win rate : 35.367%
#  -- TOTAL Games WIN : 36855 DRAW : 6793 LOSS : 67352
# ========== Training : Episode  112000  ===========
# Recent 1000 games win rate :36.702%
#  -- 1000 Games WIN : 345 DRAW : 60 LOSS : 595
# Total win rate : 35.379%
#  -- TOTAL Games WIN : 37200 DRAW : 6853 LOSS : 67947
# ========== Training : Episode  113000  ===========
# Recent 1000 games win rate :36.588%
#  -- 1000 Games WIN : 341 DRAW : 68 LOSS : 591
# Total win rate : 35.390%
#  -- TOTAL Games WIN : 37541 DRAW : 6921 LOSS : 68538
# ========== Training : Episode  114000  ===========
# Recent 1000 games win rate
# ========== Training : Episode  135000  ===========
# Recent 1000 games win rate :33.906%
#  -- 1000 Games WIN : 316 DRAW : 68 LOSS : 616
# Total win rate : 35.361%
#  -- TOTAL Games WIN : 44826 DRAW : 8234 LOSS : 81940
# ========== Training : Episode  136000  ===========
# Recent 1000 games win rate :34.861%
#  -- 1000 Games WIN : 327 DRAW : 62 LOSS : 611
# Total win rate : 35.358%
#  -- TOTAL Games WIN : 45153 DRAW : 8296 LOSS : 82551
# ========== Training : Episode  137000  ===========
# Recent 1000 games win rate :34.866%
#  -- 1000 Games WIN : 326 DRAW : 65 LOSS : 609
# Total win rate : 35.354%
#  -- TOTAL Games WIN : 45479 DRAW : 8361 LOSS : 83160
# ========== Training : Episode  138000  ===========
# Recent 1000 games win rate :34.338%
#  -- 1000 Games WIN : 319 DRAW : 71 LOSS : 610
# Total win rate : 35.347%
#  -- TOTAL Games WIN : 45798 DRAW : 8432 LOSS : 83770
# ========== Training : Episode  139000  ===========
# Recent 1000 games win rate :37.182%
#  -- 1000 Games WIN : 351 DRAW : 56 LOSS : 593
# Total win rate : 35.360%
#  -- TOTAL Games WIN : 46149 DRAW : 8488 LOSS : 84363
# ========== Training : Episode  140000  ===========
# Recent 1000 games win rate :33.227%
#  -- 1000 Games WIN : 313 DRAW : 58 LOSS : 629
# Total win rate : 35.345%
#  -- TOTAL Games WIN : 46462 DRAW : 8546 LOSS : 84992
# ========== Training : Episode  141000  ===========
# Recent 1000 games win rate :34.834%
#  -- 1000 Games WIN : 325 DRAW : 67 LOSS : 608
# Total win rate : 35.341%
#  -- TOTAL Games WIN : 46787 DRAW : 8613 LOSS : 85600
# ========== Training : Episode  142000  ===========
# Recent 1000 games win rate :34.824%
#  -- 1000 Games WIN : 327 DRAW : 61 LOSS : 612
# Total win rate : 35.337%
#  -- TOTAL Games WIN : 47114 DRAW : 8674 LOSS : 86212
# ========== Training : Episode  143000  ===========
# Recent 1000 games win rate :34.857%
#  -- 1000 Games WIN : 328 DRAW : 59 LOSS : 613
# Total win rate : 35.334%
#  -- TOTAL Games WIN : 47442 DRAW : 8733 LOSS : 86825
# ========== Training : Episode  144000  ===========
# Recent 1000 games win rate :34.304%
#  -- 1000 Games WIN : 318 DRAW : 73 LOSS : 609
# Total win rate : 35.327%
#  -- TOTAL Games WIN : 47760 DRAW : 8806 LOSS : 87434
# ========== Training : Episode  145000  ===========
# Recent 1000 games win rate :37.858%
#  -- 1000 Games WIN : 357 DRAW : 57 LOSS : 586
# Total win rate : 35.345%
#  -- TOTAL Games WIN : 48117 DRAW : 8863 LOSS : 88020
# ========== Training : Episode  146000  ===========
# Recent 1000 games win rate :35.232%
#  -- 1000 Games WIN : 334 DRAW : 52 LOSS : 614
# Total win rate : 35.344%
#  -- TOTAL Games WIN : 48451 DRAW : 8915 LOSS : 88634
# ========== Training : Episode  147000  ===========
# Recent 1000 games win rate :34.494%
#  -- 1000 Games WIN : 327 DRAW : 52 LOSS : 621
# Total win rate : 35.338%
#  -- TOTAL Games WIN : 48778 DRAW : 8967 LOSS : 89255
# ========== Training : Episode  148000  ===========
# Recent 1000 games win rate :35.144%
#  -- 1000 Games WIN : 330 DRAW : 61 LOSS : 609
# Total win rate : 35.337%
#  -- TOTAL Games WIN : 49108 DRAW : 9028 LOSS : 89864
# ========== Training : Episode  149000  ===========
# Recent 1000 games win rate :36.797%
#  -- 1000 Games WIN : 347 DRAW : 57 LOSS : 596
# Total win rate : 35.346%
#  -- TOTAL Games WIN : 49455 DRAW : 9085 LOSS : 90460
# ========== Training : Episode  150000  ===========
# Recent 1000 games win rate :36.325%
#  -- 1000 Games WIN : 344 DRAW : 53 LOSS : 603
# Total win rate : 35.353%
#  -- TOTAL Games WIN : 49799 DRAW : 9138 LOSS : 91063
# ========== Training : Episode  151000  ===========
# Recent 1000 games win rate :33.974%
#  -- 1000 Games WIN : 318 DRAW : 64 LOSS : 618
# Total win rate : 35.344%
#  -- TOTAL Games WIN : 50117 DRAW : 9202 LOSS : 91681
# ========== Training : Episode  152000  ===========
# Recent 1000 games win rate :34.894%
#  -- 1000 Games WIN : 328 DRAW : 60 LOSS : 612
# Total win rate : 35.341%
#  -- TOTAL Games WIN : 50445 DRAW : 9262 LOSS : 92293
# ========== Training : Episode  153000  ===========
# Recent 1000 games win rate
# ========== Training : Episode  171000  ===========
# Recent 1000 games win rate :33.441%
#  -- 1000 Games WIN : 312 DRAW : 67 LOSS : 621
# Total win rate : 35.343%
#  -- TOTAL Games WIN : 56767 DRAW : 10382 LOSS : 103851
# ========== Training : Episode  172000  ===========
# Recent 1000 games win rate :35.933%
#  -- 1000 Games WIN : 341 DRAW : 51 LOSS : 608
# Total win rate : 35.346%
#  -- TOTAL Games WIN : 57108 DRAW : 10433 LOSS : 104459
# ========== Training : Episode  173000  ===========
# Recent 1000 games win rate :34.563%
#  -- 1000 Games WIN : 328 DRAW : 51 LOSS : 621
# Total win rate : 35.342%
#  -- TOTAL Games WIN : 57436 DRAW : 10484 LOSS : 105080
# ========== Training : Episode  174000  ===========
# Recent 1000 games win rate :36.508%
#  -- 1000 Games WIN : 345 DRAW : 55 LOSS : 600
# Total win rate : 35.348%
#  -- TOTAL Games WIN : 57781 DRAW : 10539 LOSS : 105680
# ========== Training : Episode  175000  ===========
# Recent 1000 games win rate :33.762%
#  -- 1000 Games WIN : 315 DRAW : 67 LOSS : 618
# Total win rate : 35.339%
#  -- TOTAL Games WIN : 58096 DRAW : 10606 LOSS : 106298
# ========== Training : Episode  176000  ===========
# Recent 1000 games win rate :35.586%
#  -- 1000 Games WIN : 337 DRAW : 53 LOSS : 610
# Total win rate : 35.341%
#  -- TOTAL Games WIN : 58433 DRAW : 10659 LOSS : 106908
# ========== Training : Episode  177000  ===========
# Recent 1000 games win rate :35.150%
#  -- 1000 Games WIN : 329 DRAW : 64 LOSS : 607
# Total win rate : 35.340%
#  -- TOTAL Games WIN : 58762 DRAW : 10723 LOSS : 107515
# ========== Training : Episode  178000  ===========
# Recent 1000 games win rate :35.616%
#  -- 1000 Games WIN : 338 DRAW : 51 LOSS : 611
# Total win rate : 35.341%
#  -- TOTAL Games WIN : 59100 DRAW : 10774 LOSS : 108126
# ========== Training : Episode  179000  ===========
# Recent 1000 games win rate :34.899%
#  -- 1000 Games WIN : 327 DRAW : 63 LOSS : 610
# Total win rate : 35.339%
#  -- TOTAL Games WIN : 59427 DRAW : 10837 LOSS : 108736
# ========== Training : Episode  180000  ===========
# Recent 1000 games win rate :36.606%
#  -- 1000 Games WIN : 343 DRAW : 63 LOSS : 594
# Total win rate : 35.346%
#  -- TOTAL Games WIN : 59770 DRAW : 10900 LOSS : 109330
# ========== Training : Episode  181000  ===========
# Recent 1000 games win rate :36.508%
#  -- 1000 Games WIN : 345 DRAW : 55 LOSS : 600
# Total win rate : 35.352%
#  -- TOTAL Games WIN : 60115 DRAW : 10955 LOSS : 109930
# ========== Training : Episode  182000  ===========
# Recent 1000 games win rate :33.546%
#  -- 1000 Games WIN : 315 DRAW : 61 LOSS : 624
# Total win rate : 35.342%
#  -- TOTAL Games WIN : 60430 DRAW : 11016 LOSS : 110554
# ========== Training : Episode  183000  ===========
# Recent 1000 games win rate :35.821%
#  -- 1000 Games WIN : 336 DRAW : 62 LOSS : 602
# Total win rate : 35.345%
#  -- TOTAL Games WIN : 60766 DRAW : 11078 LOSS : 111156
# ========== Training : Episode  184000  ===========
# Recent 1000 games win rate :36.258%
#  -- 1000 Games WIN : 343 DRAW : 54 LOSS : 603
# Total win rate : 35.350%
#  -- TOTAL Games WIN : 61109 DRAW : 11132 LOSS : 111759
# ========== Training : Episode  185000  ===========
# Recent 1000 games win rate :36.769%
#  -- 1000 Games WIN : 346 DRAW : 59 LOSS : 595
# Total win rate : 35.358%
#  -- TOTAL Games WIN : 61455 DRAW : 11191 LOSS : 112354
# ========== Training : Episode  186000  ===========
# Recent 1000 games win rate :35.586%
#  -- 1000 Games WIN : 337 DRAW : 53 LOSS : 610
# Total win rate : 35.359%
#  -- TOTAL Games WIN : 61792 DRAW : 11244 LOSS : 112964
# ========== Training : Episode  187000  ===========
# Recent 1000 games win rate :34.233%
#  -- 1000 Games WIN : 317 DRAW : 74 LOSS : 609
# Total win rate : 35.353%
#  -- TOTAL Games WIN : 62109 DRAW : 11318 LOSS : 113573
# ========== Training : Episode  188000  ===========
# Recent 1000 games win rate :35.484%
#  -- 1000 Games WIN : 330 DRAW : 70 LOSS : 600
# Total win rate : 35.354%
#  -- TOTAL Games WIN : 62439 DRAW : 11388 LOSS : 114173
# ========== Training : Episode  189000  ===========
# Recent 1000 games win rate
# ========== Training : Episode  995000  ===========
# Recent 1000 games win rate :37.460%
#  -- 1000 Games WIN : 351 DRAW : 63 LOSS : 586
# Total win rate : 35.399%
#  -- TOTAL Games WIN : 331025 DRAW : 59871 LOSS : 604104
# ========== Training : Episode  996000  ===========
# Recent 1000 games win rate :34.737%
#  -- 1000 Games WIN : 330 DRAW : 50 LOSS : 620
# Total win rate : 35.398%
#  -- TOTAL Games WIN : 331355 DRAW : 59921 LOSS : 604724
# ========== Training : Episode  997000  ===========
# Recent 1000 games win rate :34.141%
#  -- 1000 Games WIN : 324 DRAW : 51 LOSS : 625
# Total win rate : 35.397%
#  -- TOTAL Games WIN : 331679 DRAW : 59972 LOSS : 605349
# ========== Training : Episode  998000  ===========
# Recent 1000 games win rate :35.095%
#  -- 1000 Games WIN : 332 DRAW : 54 LOSS : 614
# Total win rate : 35.397%
#  -- TOTAL Games WIN : 332011 DRAW : 60026 LOSS : 605963
# ========== Training : Episode  999000  ===========
# Recent 1000 games win rate :32.737%
#  -- 1000 Games WIN : 311 DRAW : 50 LOSS : 639
# Total win rate : 35.394%
#  -- TOTAL Games WIN : 332322 DRAW : 60076 LOSS : 606602
# ========== Training : Episode  1000000  ===========
# Recent 1000 games win rate :33.333%
#  -- 1000 Games WIN : 308 DRAW : 76 LOSS : 616
# Total win rate : 35.392%
#  -- TOTAL Games WIN : 332630 DRAW : 60152 LOSS : 607218

# %% [markdown]
# ## 8. 학습 결과 시각화

# %%
print("Q-value with Usable Ace")
plot_q_val(agent, usable_ace=True)
print("Q-value without Usable Ace")
plot_q_val(agent, usable_ace=False)
print("Optimal policy with Usable Ace : (RED : STICK, BLUE : HIT)")
usable_result = plot_action(agent, usable_ace=True)
print("Optimal policy without Usable Ace : (RED : STICK, BLUE : HIT)")
no_usable_result = plot_action(agent, usable_ace=False)
# Out:
# Q-value with Usable Ace
# Q-value without Usable Ace
# Optimal policy with Usable Ace : (RED : STICK, BLUE : HIT)
# Optimal policy without Usable Ace : (RED : STICK, BLUE : HIT)

# %% [markdown]
# ----
# ## 9. 과제
#
# ### 목표
# 위 코드로부터 최적 Policy를 학습시킨 Agent를 사용하여, 블랙잭 게임을 시뮬레이션한 뒤 승률을 계산.
#
# ### 초기 설정
#  - 플레이어는 1,000,000번의 에피소드로부터 최적 Policy를 학습
#  - 플레이어의 초기 자금 : 10,000 달러
#  - 플레이어는 게임 참가 시 10 달러를 지불, 결과에 따라 금액을 획득
#      - 승리 시 : 20 달러 획득
#      - 무승부 시 : 10 달러 획득
#      - 패배 시 : 0 달러 획득
#
# ### 요구사항
#  - 플레이어와 딜러가 1,000번의 게임을 진행
#  - 1,000번의 게임 후 플레이어의 승률을 계산
#  - 매 게임 별 플레이어의 소지금 변화를 그래프로 시각화
#
# #### * HINT : MonteCarlo 클래스의 generate_episode(), train() 메소드를 참고할 것
# ----
# ### (과제 1) 1,000번의 게임 진행

# %%
def PlayGame(money=10000, bet=10, win=20, draw=10, lose=0, it=1000):
    money_trace = []
    w, d, l = 0, 0, 0
    
    for i in range(it):
        money -= bet
        episode = mc_es.generate_episode(dealer, agent, deck)
        
        if episode[-1][-1] == 1:
            w += 1
            money += win
        elif episode[-1][-1] == 0:
            d += 1
            money += draw
        else:
            l += 1
            money += lose
            
        money_trace.append(money)
    
    return money_trace, w, d, l

# %%
money_trace, win, draw, lose = PlayGame()

# %% [markdown]
# ### (과제 2) 플레이어의 승률을 계산

# %%
############### 코드 작성 ##############################
print("Total win rate : {:.3f}%".format(win / (win + lose) * 100))
print(" -- TOTAL Games WIN :", win, "DRAW :", draw, "LOSS :", lose)
########################################################
# Out:
# Total win rate : 34.002%
#  -- TOTAL Games WIN : 322 DRAW : 53 LOSS : 625

# %% [markdown]
# ### (과제 3) 플레이어의 소지금 변화를 그래프로 시각화

# %%
############### 코드 작성 ##############################
plt.figure(figsize=(12, 7))

plt.plot(money_trace)
plt.xlabel('Games')
plt.ylabel('Money')
plt.show()
########################################################

# %% [markdown]
# ## 추가 과제 : 플레이어의 승률 높이기
# State를 수정하여 승률이 더 높은 policy를 찾기
#
# 기존 코드의 수정 필요
#  - 딜러는 게임이 끝났을 때, 남은 카드의 수를 확인
#  - 15장 이상이라면 해당 덱을 다음 게임에서 그대로 사용
#  - 15장 미만이라면 52장의 셔플된 새로운 카드를 기존 덱에 추가

# %%
############### 코드 작성 ##############################
class AdvancedDeck(Deck):
    def add_deck(self):
        deck = [2,3,4,5,6,7,8,9,10,10,10,10,11]
        new_deck = deck * 4
        random.shuffle(new_deck)
        self.card_deck += new_deck
        
class AdvancedAgent(Agent):
    def __init__(self):
        self.hands = list()
        self.usable_ace = list()
        self.Q_table = dict()
        self.card_count = 0
        self.deck_count = 1
        self.basic = dict()
        self.basic_setting()
        
    def basic_setting(self):
        for i in range(1, 11):
            # use_aces = False
            for j in range(8, 18):
                state = (j, False, i)
                
                if j == 17:
                    self.basic[(state)] = False
                elif j > 12 and j < 17:
                    if i > 1 and i < 7:
                        self.basic[(state)] = False
                    else:
                        self.basic[(state)] = True
                elif j == 12:
                    if i > 2 and i < 7:
                        self.basic[(state)] = False
                    else:
                        self.basic[(state)] = True
                else:
                    self.basic[(state)] = True
                        
            
            # use_aces = True
            for j in range(2, 10):
                state = (j + 11, True, i)
                
                if j > 7 and j < 10:
                    self.basic[(state)] = False
                elif j == 7:
                    if i > 1 and i < 9:
                        self.basic[(state)] = False
                    else:
                        self.basic[(state)] = True
                else:
                    self.basic[(state)] = True
        
    
    def hit(self, deck: Deck):
        """
        덱에서 새로운 카드를 뽑음
        :param deck: Deck for draw a card
        :return: None
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)
        self.card_counting(new_card)
        
    def add_deck(self):
        self.deck_count += 1

    def card_counting(self, card):
        if card < 7:
            self.card_count += 1
        elif card > 9:
            self.card_count -= 1
        
        self.card_count = self.card_count / self.deck_count

    def new_game(self):
        self.card_count = 0
        self.deck_count = 1
        
        
class AdvancedMonteCarlo(MonteCarlo):
    def generate_episode(self, dealer: Dealer, agent: Agent, deck: Deck):
        # 카드 덱, 딜러, Agent를 초기화
        if len(deck.card_deck) < 15:
            deck.add_deck()
            agent.add_deck()
        
        dealer.reset()
        agent.reset()
        agent.hit(deck)
        agent.hit(deck)
        dealer.hit(deck)
        dealer.hit(deck)

        done = False    # 에피소드의 종료 여부

        episode = list()    # 에피소드
        dealer_hand = dealer.show()
        agent.card_counting(dealer_hand)

        while not done:
            # 에피소드가 끝날 때까지 State, Action, Reward를 생성
            sums = agent.calculate_sum()
            if sums < 12:
                agent.hit(deck)
                continue

            state = (sums, bool(agent.usable_ace), dealer_hand, int(agent.card_count))
            
            if (sums, bool(agent.usable_ace), dealer_hand) in agent.basic.keys():
                action = agent.basic[(sums, bool(agent.usable_ace), dealer_hand)]
            else:
                action = agent.policy(state)
            
            
            done, reward = dealer.observation(action, agent, deck)  # 에피소드 종료 여부, Reward 계산
            
            # 생성된 State, Action, Reward를 에피소드에 추가
            episode.append([state, action, reward])

        return episode
########################################################

# %%
adv_deck = AdvancedDeck()
adv_agent = AdvancedAgent()
dealer = Dealer()
adv_mc_es = AdvancedMonteCarlo()

adv_mc_es.train(dealer, adv_agent, adv_deck, it=1000000)
# Out:
# ========== Training : Episode  1000  ===========
# Recent 1000 games win rate :45.922%
#  -- 1000 Games WIN : 411 DRAW : 105 LOSS : 484
# Total win rate : 45.922%
#  -- TOTAL Games WIN : 411 DRAW : 105 LOSS : 484
# ========== Training : Episode  2000  ===========
# Recent 1000 games win rate :47.557%
#  -- 1000 Games WIN : 438 DRAW : 79 LOSS : 483
# Total win rate : 46.751%
#  -- TOTAL Games WIN : 849 DRAW : 184 LOSS : 967
# ========== Training : Episode  3000  ===========
# Recent 1000 games win rate :47.363%
#  -- 1000 Games WIN : 440 DRAW : 71 LOSS : 489
# Total win rate : 46.958%
#  -- TOTAL Games WIN : 1289 DRAW : 255 LOSS : 1456
# ========== Training : Episode  4000  ===========
# Recent 1000 games win rate :44.641%
#  -- 1000 Games WIN : 404 DRAW : 95 LOSS : 501
# Total win rate : 46.384%
#  -- TOTAL Games WIN : 1693 DRAW : 350 LOSS : 1957
# ========== Training : Episode  5000  ===========
# Recent 1000 games win rate :46.188%
#  -- 1000 Games WIN : 418 DRAW : 95 LOSS : 487
# Total win rate : 46.345%
#  -- TOTAL Games WIN : 2111 DRAW : 445 LOSS : 2444
# ========== Training : Episode  6000  ===========
# Recent 1000 games win rate :46.025%
#  -- 1000 Games WIN : 411 DRAW : 107 LOSS : 482
# Total win rate : 46.292%
#  -- TOTAL Games WIN : 2522 DRAW : 552 LOSS : 2926
# ========== Training : Episode  7000  ===========
# Recent 1000 games win rate :46.296%
#  -- 1000 Games WIN : 425 DRAW : 82 LOSS : 493
# Total win rate : 46.293%
#  -- TOTAL Games WIN : 2947 DRAW : 634 LOSS : 3419
# ========== Training : Episode  8000  ===========
# Recent 1000 games win rate :46.493%
#  -- 1000 Games WIN : 411 DRAW : 116 LOSS : 473
# Total win rate : 46.317%
#  -- TOTAL Games WIN : 3358 DRAW : 750 LOSS : 3892
# ========== Training : Episode  9000  ===========
# Recent 1000 games win rate :46.950%
#  -- 1000 Games WIN : 431 DRAW : 82 LOSS : 487
# Total win rate : 46.388%
#  -- TOTAL Games WIN : 3789 DRAW : 832 LOSS : 4379
# ========== Training : Episode  10000  ===========
# Recent 1000 games win rate :45.916%
#  -- 1000 Games WIN : 416 DRAW : 94 LOSS : 490
# Total win rate : 46.341%
#  -- TOTAL Games WIN : 4205 DRAW : 926 LOSS : 4869
# ========== Training : Episode  11000  ===========
# Recent 1000 games win rate :47.143%
#  -- 1000 Games WIN : 429 DRAW : 90 LOSS : 481
# Total win rate : 46.414%
#  -- TOTAL Games WIN : 4634 DRAW : 1016 LOSS : 5350
# ========== Training : Episode  12000  ===========
# Recent 1000 games win rate :47.104%
#  -- 1000 Games WIN : 431 DRAW : 85 LOSS : 484
# Total win rate : 46.472%
#  -- TOTAL Games WIN : 5065 DRAW : 1101 LOSS : 5834
# ========== Training : Episode  13000  ===========
# Recent 1000 games win rate :45.683%
#  -- 1000 Games WIN : 418 DRAW : 85 LOSS : 497
# Total win rate : 46.411%
#  -- TOTAL Games WIN : 5483 DRAW : 1186 LOSS : 6331
# ========== Training : Episode  14000  ===========
# Recent 1000 games win rate :47.692%
#  -- 1000 Games WIN : 434 DRAW : 90 LOSS : 476
# Total win rate : 46.503%
#  -- TOTAL Games WIN : 5917 DRAW : 1276 LOSS : 6807
# ========== Training : Episode  15000  ===========
# Recent 1000 games win rate :47.495%
#  -- 1000 Games WIN : 436 DRAW : 82 LOSS : 482
# Total win rate : 46.569%
#  -- TOTAL Games WIN : 6353 DRAW : 1358 LOSS : 7289
# ========== Training : Episode  16000  ===========
# Recent 1000 games win rate :47.645%
#  -- 1000 Games WIN : 435 DRAW : 87 LOSS : 478
# Total win rate : 46.637%
#  -- TOTAL Games WIN : 6788 DRAW : 1445 LOSS : 7767
# ========== Training : Episode  17000  ===========
# Recent 1000 games win rate :45.154%
#  -- 1000 Games WIN : 410 DRAW : 92 LOSS : 498
# Total win rate : 46.550%
#  -- TOTAL Games WIN : 7198 DRAW : 1537 LOSS : 8265
# ========== Training : Episode  18000  ===========
# Recent 1000 games win rate :45.147%
#  -- 1000 Games WIN : 414 DRAW : 83 LOSS : 503
# Total win rate : 46.471%
#  -- TOTAL Games WIN : 7612 DRAW : 1620 LOSS : 8768
# ========== Training : Episode  19000  ===========
# Recent 1000 games win rate :49.612%
#  -- 1000 Games WIN : 447 DRAW : 99 LOSS : 454
# Total win rate : 46.635%
#  -- TOTAL Games WIN : 8059 DRAW : 1719 LOSS : 9222
# ========== Training : Episode  20000  ===========
# Recent 1000 games win rate :46.580%
#  -- 1000 Games WIN : 429 DRAW : 79 LOSS : 492
# Total win rate : 46.632%
#  -- TOTAL Games WIN : 8488 DRAW : 1798 LOSS : 9714
# ========== Training : Episode  21000  ===========
# Recent 1000 games win rate :45.714%
#  -- 1000 Games WIN : 416 DRAW : 90 LOSS : 494
# Total win rate : 46.589%
#  -- TOTAL Games WIN : 8904 DRAW : 1888 LOSS : 10208
# ========== Training : Episode  22000  ===========
# Recent 1000 games win rate :45.044%
#  -- 1000 Games WIN : 409 DRAW : 92 LOSS : 499
# Total win rate : 46.518%
#  -- TOTAL Games WIN : 9313 DRAW : 1980 LOSS : 10707
# ========== Training : Episode  23000  ===========
# Recent 1000 games win rate :45.991%
#  -- 1000 Games WIN : 413 DRAW : 102 LOSS : 485
# Total win rate : 46.496%
#  -- TOTAL Games WIN : 9726 DRAW : 2082 LOSS : 11192
# ========== Training : Episode  24000  ===========
# Recent 1000 games win rate :48.845%
#  -- 1000 Games WIN : 444 DRAW : 91 LOSS : 465
# Total win rate : 46.594%
#  -- TOTAL Games WIN : 10170 DRAW : 2173 LOSS : 11657
# ========== Training : Episode  25000  ===========
# Recent 1000 games win rate :48.208%
#  -- 1000 Games WIN : 444 DRAW : 79 LOSS : 477
# Total win rate : 46.659%
#  -- TOTAL Games WIN : 10614 DRAW : 2252 LOSS : 12134
# ========== Training : Episode  26000  ===========
# Recent 1000 games win rate :46.350%
#  -- 1000 Games WIN : 419 DRAW : 96 LOSS : 485
# Total win rate : 46.647%
#  -- TOTAL Games WIN : 11033 DRAW : 2348 LOSS : 12619
# ========== Training : Episode  27000  ===========
# Recent 1000 games win rate :44.543%
#  -- 1000 Games WIN : 400 DRAW : 102 LOSS : 498
# Total win rate : 46.570%
#  -- TOTAL Games WIN : 11433 DRAW : 2450 LOSS : 13117
# ========== Training : Episode  28000  ===========
# Recent 1000 games win rate :43.771%
#  -- 1000 Games WIN : 397 DRAW : 93 LOSS : 510
# Total win rate : 46.471%
#  -- TOTAL Games WIN : 11830 DRAW : 2543 LOSS : 13627
# ========== Training : Episode  29000  ===========
# Recent 1000 games win rate :47.619%
#  -- 1000 Games WIN : 430 DRAW : 97 LOSS : 473
# Total win rate : 46.510%
#  -- TOTAL Games WIN : 12260 DRAW : 2640 LOSS : 14100
# ========== Training : Episode  30000  ===========
# Recent 1000 games win rate :47.850%
#  -- 1000 Games WIN : 434 DRAW : 93 LOSS : 473
# Total win rate : 46.554%
#  -- TOTAL Games WIN : 12694 DRAW : 2733 LOSS : 14573
# ========== Training : Episode  31000  ===========
# Recent 1000 games win rate :43.564%
#  -- 1000 Games WIN : 396 DRAW : 91 LOSS : 513
# Total win rate : 46.458%
#  -- TOTAL Games WIN : 13090 DRAW : 2824 LOSS : 15086
# ========== Training : Episode  32000  ===========
# Recent 1000 games win rate :45.495%
#  -- 1000 Games WIN : 414 DRAW : 90 LOSS : 496
# Total win rate : 46.428%
#  -- TOTAL Games WIN : 13504 DRAW : 2914 LOSS : 15582
# ========== Training : Episode  33000  ===========
# Recent 1000 games win rate :49.890%
#  -- 1000 Games WIN : 452 DRAW : 94 LOSS : 454
# Total win rate : 46.532%
#  -- TOTAL Games WIN : 13956 DRAW : 3008 LOSS : 16036
# ========== Training : Episode  34000  ===========
# Recent 1000 games win rate :45.943%
#  -- 1000 Games WIN : 419 DRAW : 88 LOSS : 493
# Total win rate : 46.515%
#  -- TOTAL Games WIN : 14375 DRAW : 3096 LOSS : 16529
# ========== Training : Episode  35000  ===========
# Recent 1000 games win rate :46.861%
#  -- 1000 Games WIN : 418 DRAW : 108 LOSS : 474
# Total win rate : 46.525%
#  -- TOTAL Games WIN : 14793 DRAW : 3204 LOSS : 17003
# ========== Training : Episode  36000  ===========
# Recent 1000 games win rate :45.534%
#  -- 1000 Games WIN : 418 DRAW : 82 LOSS : 500
# Total win rate : 46.497%
#  -- TOTAL Games WIN : 15211 DRAW : 3286 LOSS : 17503
# ========== Training : Episode  37000  ===========
# Recent 1000 games win rate :48.783%
#  -- 1000 Games WIN : 441 DRAW : 96 LOSS : 463
# Total win rate : 46.558%
#  -- TOTAL Games WIN : 15652 DRAW : 3382 LOSS : 17966
# ========== Training : Episode  38000  ===========
# Recent 1000 games win rate :46.732%
#  -- 1000 Games WIN : 429 DRAW : 82 LOSS : 489
# Total win rate : 46.563%
#  -- TOTAL Games WIN : 16081 DRAW : 3464 LOSS : 18455
# ========== Training : Episode  39000  ===========
# Recent 1000 games win rate :46.667%
#  -- 1000 Games WIN : 427 DRAW : 85 LOSS : 488
# Total win rate : 46.566%
#  -- TOTAL Games WIN : 16508 DRAW : 3549 LOSS : 18943
# ========== Training : Episode  40000  ===========
# Recent 1000 games win rate :47.725%
#  -- 1000 Games WIN : 430 DRAW : 99 LOSS : 471
# Total win rate : 46.594%
#  -- TOTAL Games WIN : 16938 DRAW : 3648 LOSS : 19414
# ========== Training : Episode  41000  ===========
# Recent 1000 games win rate :48.840%
#  -- 1000 Games WIN : 442 DRAW : 95 LOSS : 463
# Total win rate : 46.649%
#  -- TOTAL Games WIN : 17380 DRAW : 3743 LOSS : 19877
# ========== Training : Episode  42000  ===========
# Recent 1000 games win rate :51.045%
#  -- 1000 Games WIN : 464 DRAW : 91 LOSS : 445
# Total win rate : 46.754%
#  -- TOTAL Games WIN : 17844 DRAW : 3834 LOSS : 20322
# ========== Training : Episode  43000  ===========
# Recent 1000 games win rate :45.385%
#  -- 1000 Games WIN : 418 DRAW : 79 LOSS : 503
# Total win rate : 46.721%
#  -- TOTAL Games WIN : 18262 DRAW : 3913 LOSS : 20825
# ========== Training : Episode  44000  ===========
# Recent 1000 games win rate :47.557%
#  -- 1000 Games WIN : 438 DRAW : 79 LOSS : 483
# Total win rate : 46.741%
#  -- TOTAL Games WIN : 18700 DRAW : 3992 LOSS : 21308
# ========== Training : Episode  45000  ===========
# Recent 1000 games win rate :46.000%
#  -- 1000 Games WIN : 414 DRAW : 100 LOSS : 486
# Total win rate : 46.724%
#  -- TOTAL Games WIN : 19114 DRAW : 4092 LOSS : 21794
# ========== Training : Episode  46000  ===========
# Recent 1000 games win rate :44.824%
#  -- 1000 Games WIN : 407 DRAW : 92 LOSS : 501
# Total win rate : 46.683%
#  -- TOTAL Games WIN : 19521 DRAW : 4184 LOSS : 22295
# ========== Training : Episode  47000  ===========
# Recent 1000 games win rate :48.920%
#  -- 1000 Games WIN : 453 DRAW : 74 LOSS : 473
# Total win rate : 46.732%
#  -- TOTAL Games WIN : 19974 DRAW : 4258 LOSS : 22768
# ========== Training : Episode  48000  ===========
# Recent 1000 games win rate :46.028%
#  -- 1000 Games WIN : 423 DRAW : 81 LOSS : 496
# Total win rate : 46.717%
#  -- TOTAL Games WIN : 20397 DRAW : 4339 LOSS : 23264
# ========== Training : Episode  49000  ===========
# Recent 1000 games win rate :46.077%
#  -- 1000 Games WIN : 417 DRAW : 95 LOSS : 488
# Total win rate : 46.704%
#  -- TOTAL Games WIN : 20814 DRAW : 4434 LOSS : 23752
# ========== Training : Episode  50000  ===========
# Recent 1000 games win rate :45.889%
#  -- 1000 Games WIN : 413 DRAW : 100 LOSS : 487
# Total win rate : 46.688%
#  -- TOTAL Games WIN : 21227 DRAW : 4534 LOSS : 24239
# ========== Training : Episode  51000  ===========
# Recent 1000 games win rate :45.961%
#  -- 1000 Games WIN : 421 DRAW : 84 LOSS : 495
# Total win rate : 46.673%
#  -- TOTAL Games WIN : 21648 DRAW : 4618 LOSS : 24734
# ========== Training : Episode  52000  ===========
# Recent 1000 games win rate :45.880%
#  -- 1000 Games WIN : 412 DRAW : 102 LOSS : 486
# Total win rate : 46.658%
#  -- TOTAL Games WIN : 22060 DRAW : 4720 LOSS : 25220
# ========== Training : Episode  53000  ===========
# Recent 1000 games win rate :46.593%
#  -- 1000 Games WIN : 424 DRAW : 90 LOSS : 486
# Total win rate : 46.657%
#  -- TOTAL Games WIN : 22484 DRAW : 4810 LOSS : 25706
# ========== Training : Episode  54000  ===========
# Recent 1000 games win rate :46.841%
#  -- 1000 Games WIN : 430 DRAW : 82 LOSS : 488
# Total win rate : 46.660%
#  -- TOTAL Games WIN : 22914 DRAW : 4892 LOSS : 26194
# ========== Training : Episode  55000  ===========
# Recent 1000 games win rate :48.283%
#  -- 1000 Games WIN : 436 DRAW : 97 LOSS : 467
# Total win rate : 46.690%
#  -- TOTAL Games WIN : 23350 DRAW : 4989 LOSS : 26661
# ========== Training : Episode  56000  ===========
# Recent 1000 games win rate :47.186%
#  -- 1000 Games WIN : 436 DRAW : 76 LOSS : 488
# Total win rate : 46.699%
#  -- TOTAL Games WIN : 23786 DRAW : 5065 LOSS : 27149
# ========== Training : Episode  57000  ===========
# Recent 1000 games win rate :49.229%
#  -- 1000 Games WIN : 447 DRAW : 92 LOSS : 461
# Total win rate : 46.743%
#  -- TOTAL Games WIN : 24233 DRAW : 5157 LOSS : 27610
# ========== Training : Episode  58000  ===========
# Recent 1000 games win rate :45.902%
#  -- 1000 Games WIN : 420 DRAW : 85 LOSS : 495
# Total win rate : 46.728%
#  -- TOTAL Games WIN : 24653 DRAW : 5242 LOSS : 28105
# ========== Training : Episode  59000  ===========
# Recent 1000 games win rate :48.709%
#  -- 1000 Games WIN : 434 DRAW : 109 LOSS : 457
# Total win rate : 46.761%
#  -- TOTAL Games WIN : 25087 DRAW : 5351 LOSS : 28562
# ========== Training : Episode  60000  ===========
# Recent 1000 games win rate :46.231%
#  -- 1000 Games WIN : 417 DRAW : 98 LOSS : 485
# Total win rate : 46.753%
#  -- TOTAL Games WIN : 25504 DRAW : 5449 LOSS : 29047
# ========== Training : Episode  61000  ===========
# Recent 1000 games win rate :50.665%
#  -- 1000 Games WIN : 457 DRAW : 98 LOSS : 445
# Total win rate : 46.816%
#  -- TOTAL Games WIN : 25961 DRAW : 5547 LOSS : 29492
# ========== Training : Episode  62000  ===========
# Recent 1000 games win rate :47.351%
#  -- 1000 Games WIN : 429 DRAW : 94 LOSS : 477
# Total win rate : 46.825%
#  -- TOTAL Games WIN : 26390 DRAW : 5641 LOSS : 29969
# ========== Training : Episode  63000  ===========
# Recent 1000 games win rate :43.407%
#  -- 1000 Games WIN : 395 DRAW : 90 LOSS : 515
# Total win rate : 46.771%
#  -- TOTAL Games WIN : 26785 DRAW : 5731 LOSS : 30484
# ========== Training : Episode  64000  ===========
# Recent 1000 games win rate :48.670%
#  -- 1000 Games WIN : 439 DRAW : 98 LOSS : 463
# Total win rate : 46.800%
#  -- TOTAL Games WIN : 27224 DRAW : 5829 LOSS : 30947
# ========== Training : Episode  65000  ===========
# Recent 1000 games win rate :46.550%
#  -- 1000 Games WIN : 425 DRAW : 87 LOSS : 488
# Total win rate : 46.796%
#  -- TOTAL Games WIN : 27649 DRAW : 5916 LOSS : 31435
# ========== Training : Episode  66000  ===========
# Recent 1000 games win rate :47.640%
#  -- 1000 Games WIN : 434 DRAW : 89 LOSS : 477
# Total win rate : 46.809%
#  -- TOTAL Games WIN : 28083 DRAW : 6005 LOSS : 31912
# ========== Training : Episode  67000  ===========
# Recent 1000 games win rate :47.912%
#  -- 1000 Games WIN : 436 DRAW : 90 LOSS : 474
# Total win rate : 46.825%
#  -- TOTAL Games WIN : 28519 DRAW : 6095 LOSS : 32386
# ========== Training : Episode  68000  ===========
# Recent 1000 games win rate :47.195%
#  -- 1000 Games WIN : 429 DRAW : 91 LOSS : 480
# Total win rate : 46.831%
#  -- TOTAL Games WIN : 28948 DRAW : 6186 LOSS : 32866
# ========== Training : Episode  69000  ===========
# Recent 1000 games win rate :46.401%
#  -- 1000 Games WIN : 419 DRAW : 97 LOSS : 484
# Total win rate : 46.825%
#  -- TOTAL Games WIN : 29367 DRAW : 6283 LOSS : 33350
# ========== Training : Episode  70000  ===========
# Recent 1000 games win rate :46.762%
#  -- 1000 Games WIN : 426 DRAW : 89 LOSS : 485
# Total win rate : 46.824%
#  -- TOTAL Games WIN : 29793 DRAW : 6372 LOSS : 33835
# ========== Training : Episode  71000  ===========
# Recent 1000 games win rate :45.833%
#  -- 1000 Games WIN : 418 DRAW : 88 LOSS : 494
# Total win rate : 46.810%
#  -- TOTAL Games WIN : 30211 DRAW : 6460 LOSS : 34329
# ========== Training : Episode  72000  ===========
# Recent 1000 games win rate :45.055%
#  -- 1000 Games WIN : 410 DRAW : 90 LOSS : 500
# Total win rate : 46.785%
#  -- TOTAL Games WIN : 30621 DRAW : 6550 LOSS : 34829
# ========== Training : Episode  73000  ===========
# Recent 1000 games win rate :44.711%
#  -- 1000 Games WIN : 410 DRAW : 83 LOSS : 507
# Total win rate : 46.757%
#  -- TOTAL Games WIN : 31031 DRAW : 6633 LOSS : 35336
# ========== Training : Episode  74000  ===========
# Recent 1000 games win rate :46.222%
#  -- 1000 Games WIN : 416 DRAW : 100 LOSS : 484
# Total win rate : 46.750%
#  -- TOTAL Games WIN : 31447 DRAW : 6733 LOSS : 35820
# ========== Training : Episode  75000  ===========
# Recent 1000 games win rate :46.946%
#  -- 1000 Games WIN : 415 DRAW : 116 LOSS : 469
# Total win rate : 46.752%
#  -- TOTAL Games WIN : 31862 DRAW : 6849 LOSS : 36289
# ========== Training : Episode  76000  ===========
# Recent 1000 games win rate :48.775%
#  -- 1000 Games WIN : 438 DRAW : 102 LOSS : 460
# Total win rate : 46.778%
#  -- TOTAL Games WIN : 32300 DRAW : 6951 LOSS : 36749
# ========== Training : Episode  77000  ===========
# Recent 1000 games win rate :45.415%
#  -- 1000 Games WIN : 416 DRAW : 84 LOSS : 500
# Total win rate : 46.761%
#  -- TOTAL Games WIN : 32716 DRAW : 7035 LOSS : 37249
# ========== Training : Episode  78000  ===========
# Recent 1000 games win rate :48.827%
#  -- 1000 Games WIN : 437 DRAW : 105 LOSS : 458
# Total win rate : 46.787%
#  -- TOTAL Games WIN : 33153 DRAW : 7140 LOSS : 37707
# ========== Training : Episode  79000  ===========
# Recent 1000 games win rate :47.661%
#  -- 1000 Games WIN : 438 DRAW : 81 LOSS : 481
# Total win rate : 46.798%
#  -- TOTAL Games WIN : 33591 DRAW : 7221 LOSS : 38188
# ========== Training : Episode  80000  ===========
# Recent 1000 games win rate :45.714%
#  -- 1000 Games WIN : 416 DRAW : 90 LOSS : 494
# Total win rate : 46.784%
#  -- TOTAL Games WIN : 34007 DRAW : 7311 LOSS : 38682
# ========== Training : Episode  81000  ===========
# Recent 1000 games win rate :46.352%
#  -- 1000 Games WIN : 413 DRAW : 109 LOSS : 478
# Total win rate : 46.779%
#  -- TOTAL Games WIN : 34420 DRAW : 7420 LOSS : 39160
# ========== Training : Episode  82000  ===========
# Recent 1000 games win rate :43.938%
#  -- 1000 Games WIN : 395 DRAW : 101 LOSS : 504
# Total win rate : 46.745%
#  -- TOTAL Games WIN : 34815 DRAW : 7521 LOSS : 39664
# ========== Training : Episode  83000  ===========
# Recent 1000 games win rate :45.989%
#  -- 1000 Games WIN : 407 DRAW : 115 LOSS : 478
# Total win rate : 46.736%
#  -- TOTAL Games WIN : 35222 DRAW : 7636 LOSS : 40142
# ========== Training : Episode  84000  ===========
# Recent 1000 games win rate :45.415%
#  -- 1000 Games WIN : 421 DRAW : 73 LOSS : 506
# Total win rate : 46.720%
#  -- TOTAL Games WIN : 35643 DRAW : 7709 LOSS : 40648
# ========== Training : Episode  85000  ===========
# Recent 1000 games win rate :44.978%
#  -- 1000 Games WIN : 412 DRAW : 84 LOSS : 504
# Total win rate : 46.699%
#  -- TOTAL Games WIN : 36055 DRAW : 7793 LOSS : 41152
# ========== Training : Episode  86000  ===========
# Recent 1000 games win rate :44.714%
#  -- 1000 Games WIN : 406 DRAW : 92 LOSS : 502
# Total win rate : 46.676%
#  -- TOTAL Games WIN : 36461 DRAW : 7885 LOSS : 41654
# ========== Training : Episode  87000  ===========
# Recent 1000 games win rate :47.774%
#  -- 1000 Games WIN : 440 DRAW : 79 LOSS : 481
# Total win rate : 46.689%
#  -- TOTAL Games WIN : 36901 DRAW : 7964 LOSS : 42135
# ========== Training : Episode  88000  ===========
# Recent 1000 games win rate :47.903%
#  -- 1000 Games WIN : 434 DRAW : 94 LOSS : 472
# Total win rate : 46.703%
#  -- TOTAL Games WIN : 37335 DRAW : 8058 LOSS : 42607
# ========== Training : Episode  89000  ===========
# Recent 1000 games win rate :46.858%
#  -- 1000 Games WIN : 425 DRAW : 93 LOSS : 482
# Total win rate : 46.704%
#  -- TOTAL Games WIN : 37760 DRAW : 8151 LOSS : 43089
# ========== Training : Episode  90000  ===========
# Recent 1000 games win rate :44.978%
#  -- 1000 Games WIN : 403 DRAW : 104 LOSS : 493
# Total win rate : 46.685%
#  -- TOTAL Games WIN : 38163 DRAW : 8255 LOSS : 43582
# ========== Training : Episode  91000  ===========
# Recent 1000 games win rate :48.169%
#  -- 1000 Games WIN : 434 DRAW : 99 LOSS : 467
# Total win rate : 46.702%
#  -- TOTAL Games WIN : 38597 DRAW : 8354 LOSS : 44049
# ========== Training : Episode  92000  ===========
# Recent 1000 games win rate :47.007%
#  -- 1000 Games WIN : 424 DRAW : 98 LOSS : 478
# Total win rate : 46.705%
#  -- TOTAL Games WIN : 39021 DRAW : 8452 LOSS : 44527
# ========== Training : Episode  93000  ===========
# Recent 1000 games win rate :46.923%
#  -- 1000 Games WIN : 427 DRAW : 90 LOSS : 483
# Total win rate : 46.707%
#  -- TOTAL Games WIN : 39448 DRAW : 8542 LOSS : 45010
# ========== Training : Episode  94000  ===========
# Recent 1000 games win rate :46.247%
#  -- 1000 Games WIN : 419 DRAW : 94 LOSS : 487
# Total win rate : 46.702%
#  -- TOTAL Games WIN : 39867 DRAW : 8636 LOSS : 45497
# ========== Training : Episode  95000  ===========
# Recent 1000 games win rate :44.896%
#  -- 1000 Games WIN : 409 DRAW : 89 LOSS : 502
# Total win rate : 46.683%
#  -- TOTAL Games WIN : 40276 DRAW : 8725 LOSS : 45999
# ========== Training : Episode  96000  ===========
# Recent 1000 games win rate :44.127%
#  -- 1000 Games WIN : 402 DRAW : 89 LOSS : 509
# Total win rate : 46.657%
#  -- TOTAL Games WIN : 40678 DRAW : 8814 LOSS : 46508
# ========== Training : Episode  97000  ===========
# Recent 1000 games win rate :44.066%
#  -- 1000 Games WIN : 401 DRAW : 90 LOSS : 509
# Total win rate : 46.630%
#  -- TOTAL Games WIN : 41079 DRAW : 8904 LOSS : 47017
# ========== Training : Episode  98000  ===========
# Recent 1000 games win rate :44.027%
#  -- 1000 Games WIN : 398 DRAW : 96 LOSS : 506
# Total win rate : 46.603%
#  -- TOTAL Games WIN : 41477 DRAW : 9000 LOSS : 47523
# ========== Training : Episode  99000  ===========
# Recent 1000 games win rate :43.825%
#  -- 1000 Games WIN : 401 DRAW : 85 LOSS : 514
# Total win rate : 46.575%
#  -- TOTAL Games WIN : 41878 DRAW : 9085 LOSS : 48037
# ========== Training : Episode  100000  ===========
# Recent 1000 games win rate :46.909%
#  -- 1000 Games WIN : 425 DRAW : 94 LOSS : 481
# Total win rate : 46.578%
#  -- TOTAL Games WIN : 42303 DRAW : 9179 LOSS : 48518
# ========== Training : Episode  101000  ===========
# Recent 1000 games win rate :45.958%
#  -- 1000 Games WIN : 415 DRAW : 97 LOSS : 488
# Total win rate : 46.572%
#  -- TOTAL Games WIN : 42718 DRAW : 9276 LOSS : 49006
# ========== Training : Episode  102000  ===========
# Recent 1000 games win rate :46.968%
#  -- 1000 Games WIN : 426 DRAW : 93 LOSS : 481
# Total win rate : 46.576%
#  -- TOTAL Games WIN : 43144 DRAW : 9369 LOSS : 49487
# ========== Training : Episode  103000  ===========
# Recent 1000 games win rate :46.102%
#  -- 1000 Games WIN : 414 DRAW : 102 LOSS : 484
# Total win rate : 46.572%
#  -- TOTAL Games WIN : 43558 DRAW : 9471 LOSS : 49971
# ========== Training : Episode  104000  ===========
# Recent 1000 games win rate :43.440%
#  -- 1000 Games WIN : 394 DRAW : 93 LOSS : 513
# Total win rate : 46.542%
#  -- TOTAL Games WIN : 43952 DRAW : 9564 LOSS : 50484
# ========== Training : Episode  105000  ===========
# Recent 1000 games win rate :45.183%
#  -- 1000 Games WIN : 408 DRAW : 97 LOSS : 495
# Total win rate : 46.529%
#  -- TOTAL Games WIN : 44360 DRAW : 9661 LOSS : 50979
# ========== Training : Episode  106000  ===========
# Recent 1000 games win rate :45.204%
#  -- 1000 Games WIN : 410 DRAW : 93 LOSS : 497
# Total win rate : 46.516%
#  -- TOTAL Games WIN : 44770 DRAW : 9754 LOSS : 51476
# ========== Training : Episode  107000  ===========
# Recent 1000 games win rate :48.640%
#  -- 1000 Games WIN : 447 DRAW : 81 LOSS : 472
# Total win rate : 46.536%
#  -- TOTAL Games WIN : 45217 DRAW : 9835 LOSS : 51948
# ========== Training : Episode  108000  ===========
# Recent 1000 games win rate :47.935%
#  -- 1000 Games WIN : 441 DRAW : 80 LOSS : 479
# Total win rate : 46.549%
#  -- TOTAL Games WIN : 45658 DRAW : 9915 LOSS : 52427
# ========== Training : Episode  109000  ===========
# Recent 1000 games win rate :48.842%
#  -- 1000 Games WIN : 443 DRAW : 93 LOSS : 464
# Total win rate : 46.570%
#  -- TOTAL Games WIN : 46101 DRAW : 10008 LOSS : 52891
# ========== Training : Episode  110000  ===========
# Recent 1000 games win rate :50.000%
#  -- 1000 Games WIN : 451 DRAW : 98 LOSS : 451
# Total win rate : 46.601%
#  -- TOTAL Games WIN : 46552 DRAW : 10106 LOSS : 53342
# ========== Training : Episode  111000  ===========
# Recent 1000 games win rate :46.535%
#  -- 1000 Games WIN : 423 DRAW : 91 LOSS : 486
# Total win rate : 46.601%
#  -- TOTAL Games WIN : 46975 DRAW : 10197 LOSS : 53828
# ========== Training : Episode  112000  ===========
# Recent 1000 games win rate :46.719%
#  -- 1000 Games WIN : 420 DRAW : 101 LOSS : 479
# Total win rate : 46.602%
#  -- TOTAL Games WIN : 47395 DRAW : 10298 LOSS : 54307
# ========== Training : Episode  113000  ===========
# Recent 1000 games win rate :46.563%
#  -- 1000 Games WIN : 420 DRAW : 98 LOSS : 482
# Total win rate : 46.601%
#  -- TOTAL Games WIN : 47815 DRAW : 10396 LOSS : 54789
# ========== Training : Episode  114000  ===========
# Recent 1000 games win rate :43.921%
#  -- 1000 Games WIN : 401 DRAW : 87 LOSS : 512
# Total win rate : 46.578%
#  -- TOTAL Games WIN : 48216 DRAW : 10483 LOSS : 55301
# ========== Training : Episode  115000  ===========
# Recent 1000 games win rate :46.491%
#  -- 1000 Games WIN : 424 DRAW : 88 LOSS : 488
# Total win rate : 46.577%
#  -- TOTAL Games WIN : 48640 DRAW : 10571 LOSS : 55789
# ========== Training : Episode  116000  ===========
# Recent 1000 games win rate :46.703%
#  -- 1000 Games WIN : 432 DRAW : 75 LOSS : 493
# Total win rate : 46.578%
#  -- TOTAL Games WIN : 49072 DRAW : 10646 LOSS : 56282
# ========== Training : Episode  117000  ===========
# Recent 1000 games win rate :45.815%
#  -- 1000 Games WIN : 427 DRAW : 68 LOSS : 505
# Total win rate : 46.572%
#  -- TOTAL Games WIN : 49499 DRAW : 10714 LOSS : 56787
# ========== Training : Episode  118000  ===========
# Recent 1000 games win rate :46.512%
#  -- 1000 Games WIN : 420 DRAW : 97 LOSS : 483
# Total win rate : 46.571%
#  -- TOTAL Games WIN : 49919 DRAW : 10811 LOSS : 57270
# ========== Training : Episode  119000  ===========
# Recent 1000 games win rate :47.072%
#  -- 1000 Games WIN : 434 DRAW : 78 LOSS : 488
# Total win rate : 46.575%
#  -- TOTAL Games WIN : 50353 DRAW : 10889 LOSS : 57758
# ========== Training : Episode  120000  ===========
# Recent 1000 games win rate :42.842%
#  -- 1000 Games WIN : 395 DRAW : 78 LOSS : 527
# Total win rate : 46.544%
#  -- TOTAL Games WIN : 50748 DRAW : 10967 LOSS : 58285
# ========== Training : Episode  121000  ===========
# Recent 1000 games win rate :47.368%
#  -- 1000 Games WIN : 432 DRAW : 88 LOSS : 480
# Total win rate : 46.551%
#  -- TOTAL Games WIN : 51180 DRAW : 11055 LOSS : 58765
# ========== Training : Episode  122000  ===========
# Recent 1000 games win rate :48.013%
#  -- 1000 Games WIN : 435 DRAW : 94 LOSS : 471
# Total win rate : 46.563%
#  -- TOTAL Games WIN : 51615 DRAW : 11149 LOSS : 59236
# ========== Training : Episode  123000  ===========
# Recent 1000 games win rate :46.307%
#  -- 1000 Games WIN : 420 DRAW : 93 LOSS : 487
# Total win rate : 46.560%
#  -- TOTAL Games WIN : 52035 DRAW : 11242 LOSS : 59723
# ========== Training : Episode  124000  ===========
# Recent 1000 games win rate :47.065%
#  -- 1000 Games WIN : 425 DRAW : 97 LOSS : 478
# Total win rate : 46.564%
#  -- TOTAL Games WIN : 52460 DRAW : 11339 LOSS : 60201
# ========== Training : Episode  125000  ===========
# Recent 1000 games win rate :48.458%
#  -- 1000 Games WIN : 440 DRAW : 92 LOSS : 468
# Total win rate : 46.580%
#  -- TOTAL Games WIN : 52900 DRAW : 11431 LOSS : 60669
# ========== Training : Episode  126000  ===========
# Recent 1000 games win rate :46.696%
#  -- 1000 Games WIN : 431 DRAW : 77 LOSS : 492
# Total win rate : 46.581%
#  -- TOTAL Games WIN : 53331 DRAW : 11508 LOSS : 61161
# ========== Training : Episode  127000  ===========
# Recent 1000 games win rate :46.601%
#  -- 1000 Games WIN : 425 DRAW : 88 LOSS : 487
# Total win rate : 46.581%
#  -- TOTAL Games WIN : 53756 DRAW : 11596 LOSS : 61648
# ========== Training : Episode  128000  ===========
# Recent 1000 games win rate :46.704%
#  -- 1000 Games WIN : 418 DRAW : 105 LOSS : 477
# Total win rate : 46.582%
#  -- TOTAL Games WIN : 54174 DRAW : 11701 LOSS : 62125
# ========== Training : Episode  129000  ===========
# Recent 1000 games win rate :45.577%
#  -- 1000 Games WIN : 407 DRAW : 107 LOSS : 486
# Total win rate : 46.574%
#  -- TOTAL Games WIN : 54581 DRAW : 11808 LOSS : 62611
# ========== Training : Episode  130000  ===========
# Recent 1000 games win rate :46.044%
#  -- 1000 Games WIN : 419 DRAW : 90 LOSS : 491
# Total win rate : 46.570%
#  -- TOTAL Games WIN : 55000 DRAW : 11898 LOSS : 63102
# ========== Training : Episode  131000  ===========
# Recent 1000 games win rate :47.630%
#  -- 1000 Games WIN : 432 DRAW : 93 LOSS : 475
# Total win rate : 46.578%
#  -- TOTAL Games WIN : 55432 DRAW : 11991 LOSS : 63577
# ========== Training : Episode  132000  ===========
# Recent 1000 games win rate :42.747%
#  -- 1000 Games WIN : 389 DRAW : 90 LOSS : 521
# Total win rate : 46.549%
#  -- TOTAL Games WIN : 55821 DRAW : 12081 LOSS : 64098
# ========== Training : Episode  133000  ===========
# Recent 1000 games win rate :47.065%
#  -- 1000 Games WIN : 433 DRAW : 80 LOSS : 487
# Total win rate : 46.553%
#  -- TOTAL Games WIN : 56254 DRAW : 12161 LOSS : 64585
# ========== Training : Episode  134000  ===========
# Recent 1000 games win rate :44.358%
#  -- 1000 Games WIN : 401 DRAW : 96 LOSS : 503
# Total win rate : 46.537%
#  -- TOTAL Games WIN : 56655 DRAW : 12257 LOSS : 65088
# ========== Training : Episode  135000  ===========
# Recent 1000 games win rate :43.771%
#  -- 1000 Games WIN : 397 DRAW : 93 LOSS : 510
# Total win rate : 46.516%
#  -- TOTAL Games WIN : 57052 DRAW : 12350 LOSS : 65598
# ========== Training : Episode  136000  ===========
# Recent 1000 games win rate :47.368%
#  -- 1000 Games WIN : 432 DRAW : 88 LOSS : 480
# Total win rate : 46.522%
#  -- TOTAL Games WIN : 57484 DRAW : 12438 LOSS : 66078
# ========== Training : Episode  137000  ===========
# Recent 1000 games win rate :46.837%
#  -- 1000 Games WIN : 422 DRAW : 99 LOSS : 479
# Total win rate : 46.525%
#  -- TOTAL Games WIN : 57906 DRAW : 12537 LOSS : 66557
# ========== Training : Episode  138000  ===========
# Recent 1000 games win rate :46.382%
#  -- 1000 Games WIN : 423 DRAW : 88 LOSS : 489
# Total win rate : 46.524%
#  -- TOTAL Games WIN : 58329 DRAW : 12625 LOSS : 67046
# ========== Training : Episode  139000  ===========
# Recent 1000 games win rate :46.719%
#  -- 1000 Games WIN : 420 DRAW : 101 LOSS : 479
# Total win rate : 46.525%
#  -- TOTAL Games WIN : 58749 DRAW : 12726 LOSS : 67525
# ========== Training : Episode  140000  ===========
# Recent 1000 games win rate :49.391%
#  -- 1000 Games WIN : 446 DRAW : 97 LOSS : 457
# Total win rate : 46.545%
#  -- TOTAL Games WIN : 59195 DRAW : 12823 LOSS : 67982
# ========== Training : Episode  141000  ===========
# Recent 1000 games win rate :48.189%
#  -- 1000 Games WIN : 439 DRAW : 89 LOSS : 472
# Total win rate : 46.557%
#  -- TOTAL Games WIN : 59634 DRAW : 12912 LOSS : 68454
# ========== Training : Episode  142000  ===========
# Recent 1000 games win rate :46.078%
#  -- 1000 Games WIN : 423 DRAW : 82 LOSS : 495
# Total win rate : 46.554%
#  -- TOTAL Games WIN : 60057 DRAW : 12994 LOSS : 68949
# ========== Training : Episode  143000  ===========
# Recent 1000 games win rate :48.649%
#  -- 1000 Games WIN : 450 DRAW : 75 LOSS : 475
# Total win rate : 46.569%
#  -- TOTAL Games WIN : 60507 DRAW : 13069 LOSS : 69424
# ========== Training : Episode  144000  ===========
# Recent 1000 games win rate :48.610%
#  -- 1000 Games WIN : 437 DRAW : 101 LOSS : 462
# Total win rate : 46.583%
#  -- TOTAL Games WIN : 60944 DRAW : 13170 LOSS : 69886
# ========== Training : Episode  145000  ===========
# Recent 1000 games win rate :46.061%
#  -- 1000 Games WIN : 421 DRAW : 86 LOSS : 493
# Total win rate : 46.579%
#  -- TOTAL Games WIN : 61365 DRAW : 13256 LOSS : 70379
# ========== Training : Episode  146000  ===========
# Recent 1000 games win rate :43.377%
#  -- 1000 Games WIN : 393 DRAW : 94 LOSS : 513
# Total win rate : 46.557%
#  -- TOTAL Games WIN : 61758 DRAW : 13350 LOSS : 70892
# ========== Training : Episode  147000  ===========
# Recent 1000 games win rate :47.525%
#  -- 1000 Games WIN : 432 DRAW : 91 LOSS : 477
# Total win rate : 46.564%
#  -- TOTAL Games WIN : 62190 DRAW : 13441 LOSS : 71369
# ========== Training : Episode  148000  ===========
# Recent 1000 games win rate :47.677%
#  -- 1000 Games WIN : 431 DRAW : 96 LOSS : 473
# Total win rate : 46.571%
#  -- TOTAL Games WIN : 62621 DRAW : 13537 LOSS : 71842
# ========== Training : Episode  149000  ===========
# Recent 1000 games win rate :44.553%
#  -- 1000 Games WIN : 409 DRAW : 82 LOSS : 509
# Total win rate : 46.557%
#  -- TOTAL Games WIN : 63030 DRAW : 13619 LOSS : 72351
# ========== Training : Episode  150000  ===========
# Recent 1000 games win rate :47.473%
#  -- 1000 Games WIN : 432 DRAW : 90 LOSS : 478
# Total win rate : 46.564%
#  -- TOTAL Games WIN : 63462 DRAW : 13709 LOSS : 72829
# ========== Training : Episode  151000  ===========
# Recent 1000 games win rate :49.727%
#  -- 1000 Games WIN : 455 DRAW : 85 LOSS : 460
# Total win rate : 46.585%
#  -- TOTAL Games WIN : 63917 DRAW : 13794 LOSS : 73289
# ========== Training : Episode  152000  ===========
# Recent 1000 games win rate :48.249%
#  -- 1000 Games WIN : 441 DRAW : 86 LOSS : 473
# Total win rate : 46.596%
#  -- TOTAL Games WIN : 64358 DRAW : 13880 LOSS : 73762
# ========== Training : Episode  153000  ===========
# Recent 1000 games win rate :47.826%
#  -- 1000 Games WIN : 440 DRAW : 80 LOSS : 480
# Total win rate : 46.604%
#  -- TOTAL Games WIN : 64798 DRAW : 13960 LOSS : 74242
# ========== Training : Episode  154000  ===========
# Recent 1000 games win rate :45.884%
#  -- 1000 Games WIN : 418 DRAW : 89 LOSS : 493
# Total win rate : 46.599%
#  -- TOTAL Games WIN : 65216 DRAW : 14049 LOSS : 74735
# ========== Training : Episode  155000  ===========
# Recent 1000 games win rate :44.615%
#  -- 1000 Games WIN : 406 DRAW : 90 LOSS : 504
# Total win rate : 46.586%
#  -- TOTAL Games WIN : 65622 DRAW : 14139 LOSS : 75239
# ========== Training : Episode  156000  ===========
# Recent 1000 games win rate :50.433%
#  -- 1000 Games WIN : 466 DRAW : 76 LOSS : 458
# Total win rate : 46.611%
#  -- TOTAL Games WIN : 66088 DRAW : 14215 LOSS : 75697
# ========== Training : Episode  157000  ===========
# Recent 1000 games win rate :47.059%
#  -- 1000 Games WIN : 432 DRAW : 82 LOSS : 486
# Total win rate : 46.614%
#  -- TOTAL Games WIN : 66520 DRAW : 14297 LOSS : 76183
# ========== Training : Episode  158000  ===========
# Recent 1000 games win rate :50.000%
#  -- 1000 Games WIN : 456 DRAW : 88 LOSS : 456
# Total win rate : 46.636%
#  -- TOTAL Games WIN : 66976 DRAW : 14385 LOSS : 76639
# ========== Training : Episode  159000  ===========
# Recent 1000 games win rate :46.988%
#  -- 1000 Games WIN : 429 DRAW : 87 LOSS : 484
# Total win rate : 46.638%
#  -- TOTAL Games WIN : 67405 DRAW : 14472 LOSS : 77123
# ========== Training : Episode  160000  ===========
# Recent 1000 games win rate :48.299%
#  -- 1000 Games WIN : 440 DRAW : 89 LOSS : 471
# Total win rate : 46.648%
#  -- TOTAL Games WIN : 67845 DRAW : 14561 LOSS : 77594
# ========== Training : Episode  161000  ===========
# Recent 1000 games win rate :49.668%
#  -- 1000 Games WIN : 449 DRAW : 96 LOSS : 455
# Total win rate : 46.667%
#  -- TOTAL Games WIN : 68294 DRAW : 14657 LOSS : 78049
# ========== Training : Episode  162000  ===========
# Recent 1000 games win rate :48.908%
#  -- 1000 Games WIN : 448 DRAW : 84 LOSS : 468
# Total win rate : 46.681%
#  -- TOTAL Games WIN : 68742 DRAW : 14741 LOSS : 78517
# ========== Training : Episode  163000  ===========
# Recent 1000 games win rate :46.282%
#  -- 1000 Games WIN : 417 DRAW : 99 LOSS : 484
# Total win rate : 46.679%
#  -- TOTAL Games WIN : 69159 DRAW : 14840 LOSS : 79001
# ========== Training : Episode  164000  ===========
# Recent 1000 games win rate :45.535%
#  -- 1000 Games WIN : 413 DRAW : 93 LOSS : 494
# Total win rate : 46.672%
#  -- TOTAL Games WIN : 69572 DRAW : 14933 LOSS : 79495
# ========== Training : Episode  165000  ===========
# Recent 1000 games win rate :46.137%
#  -- 1000 Games WIN : 418 DRAW : 94 LOSS : 488
# Total win rate : 46.668%
#  -- TOTAL Games WIN : 69990 DRAW : 15027 LOSS : 79983
# ========== Training : Episode  166000  ===========
# Recent 1000 games win rate :45.256%
#  -- 1000 Games WIN : 415 DRAW : 83 LOSS : 502
# Total win rate : 46.660%
#  -- TOTAL Games WIN : 70405 DRAW : 15110 LOSS : 80485
# ========== Training : Episode  167000  ===========
# Recent 1000 games win rate :48.104%
#  -- 1000 Games WIN : 444 DRAW : 77 LOSS : 479
# Total win rate : 46.669%
#  -- TOTAL Games WIN : 70849 DRAW : 15187 LOSS : 80964
# ========== Training : Episode  168000  ===========
# Recent 1000 games win rate :46.254%
#  -- 1000 Games WIN : 426 DRAW : 79 LOSS : 495
# Total win rate : 46.666%
#  -- TOTAL Games WIN : 71275 DRAW : 15266 LOSS : 81459
# ========== Training : Episode  169000  ===========
# Recent 1000 games win rate :46.778%
#  -- 1000 Games WIN : 421 DRAW : 100 LOSS : 479
# Total win rate : 46.667%
#  -- TOTAL Games WIN : 71696 DRAW : 15366 LOSS : 81938
# ========== Training : Episode  170000  ===========
# Recent 1000 games win rate :41.540%
#  -- 1000 Games WIN : 383 DRAW : 78 LOSS : 539
# Total win rate : 46.636%
#  -- TOTAL Games WIN : 72079 DRAW : 15444 LOSS : 82477
# ========== Training : Episode  171000  ===========
# Recent 1000 games win rate :50.497%
#  -- 1000 Games WIN : 457 DRAW : 95 LOSS : 448
# Total win rate : 46.659%
#  -- TOTAL Games WIN : 72536 DRAW : 15539 LOSS : 82925
# ========== Training : Episode  172000  ===========
# Recent 1000 games win rate :45.038%
#  -- 1000 Games WIN : 413 DRAW : 83 LOSS : 504
# Total win rate : 46.649%
#  -- TOTAL Games WIN : 72949 DRAW : 15622 LOSS : 83429
# ========== Training : Episode  173000  ===========
# Recent 1000 games win rate :44.797%
#  -- 1000 Games WIN : 409 DRAW : 87 LOSS : 504
# Total win rate : 46.638%
#  -- TOTAL Games WIN : 73358 DRAW : 15709 LOSS : 83933
# ========== Training : Episode  174000  ===========
# Recent 1000 games win rate :45.655%
#  -- 1000 Games WIN : 415 DRAW : 91 LOSS : 494
# Total win rate : 46.633%
#  -- TOTAL Games WIN : 73773 DRAW : 15800 LOSS : 84427
# ========== Training : Episode  175000  ===========
# Recent 1000 games win rate :46.571%
#  -- 1000 Games WIN : 421 DRAW : 96 LOSS : 483
# Total win rate : 46.632%
#  -- TOTAL Games WIN : 74194 DRAW : 15896 LOSS : 84910
# ========== Training : Episode  176000  ===========
# Recent 1000 games win rate :49.889%
#  -- 1000 Games WIN : 448 DRAW : 102 LOSS : 450
# Total win rate : 46.651%
#  -- TOTAL Games WIN : 74642 DRAW : 15998 LOSS : 85360
# ========== Training : Episode  177000  ===========
# Recent 1000 games win rate :44.493%
#  -- 1000 Games WIN : 404 DRAW : 92 LOSS : 504
# Total win rate : 46.638%
#  -- TOTAL Games WIN : 75046 DRAW : 16090 LOSS : 85864
# ========== Training : Episode  178000  ===========
# Recent 1000 games win rate :46.046%
#  -- 1000 Games WIN : 425 DRAW : 77 LOSS : 498
# Total win rate : 46.635%
#  -- TOTAL Games WIN : 75471 DRAW : 16167 LOSS : 86362
# ========== Training : Episode  179000  ===========
# Recent 1000 games win rate :47.677%
#  -- 1000 Games WIN : 431 DRAW : 96 LOSS : 473
# Total win rate : 46.641%
#  -- TOTAL Games WIN : 75902 DRAW : 16263 LOSS : 86835
# ========== Training : Episode  180000  ===========
# Recent 1000 games win rate :47.328%
#  -- 1000 Games WIN : 434 DRAW : 83 LOSS : 483
# Total win rate : 46.645%
#  -- TOTAL Games WIN : 76336 DRAW : 16346 LOSS : 87318
# ========== Training : Episode  181000  ===========
# Recent 1000 games win rate :45.435%
#  -- 1000 Games WIN : 413 DRAW : 91 LOSS : 496
# Total win rate : 46.638%
#  -- TOTAL Games WIN : 76749 DRAW : 16437 LOSS : 87814
# ========== Training : Episode  182000  ===========
# Recent 1000 games win rate :45.444%
#  -- 1000 Games WIN : 409 DRAW : 100 LOSS : 491
# Total win rate : 46.632%
#  -- TOTAL Games WIN : 77158 DRAW : 16537 LOSS : 88305
# ========== Training : Episode  183000  ===========
# Recent 1000 games win rate :48.017%
#  -- 1000 Games WIN : 448 DRAW : 67 LOSS : 485
# Total win rate : 46.639%
#  -- TOTAL Games WIN : 77606 DRAW : 16604 LOSS : 88790
# ========== Training : Episode  184000  ===========
# Recent 1000 games win rate :46.697%
#  -- 1000 Games WIN : 417 DRAW : 107 LOSS : 476
# Total win rate : 46.640%
#  -- TOTAL Games WIN : 78023 DRAW : 16711 LOSS : 89266
# ========== Training : Episode  185000  ===========
# Recent 1000 games win rate :45.119%
#  -- 1000 Games WIN : 416 DRAW : 78 LOSS : 506
# Total win rate : 46.631%
#  -- TOTAL Games WIN : 78439 DRAW : 16789 LOSS : 89772
# ========== Training : Episode  186000  ===========
# Recent 1000 games win rate :46.512%
#  -- 1000 Games WIN : 420 DRAW : 97 LOSS : 483
# Total win rate : 46.631%
#  -- TOTAL Games WIN : 78859 DRAW : 16886 LOSS : 90255
# ========== Training : Episode  187000  ===========
# Recent 1000 games win rate :44.699%
#  -- 1000 Games WIN : 409 DRAW : 85 LOSS : 506
# Total win rate : 46.620%
#  -- TOTAL Games WIN : 79268 DRAW : 16971 LOSS : 90761
# ========== Training : Episode  188000  ===========
# Recent 1000 games win rate :46.552%
#  -- 1000 Games WIN : 432 DRAW : 72 LOSS : 496
# Total win rate : 46.620%
#  -- TOTAL Games WIN : 79700 DRAW : 17043 LOSS : 91257
# ========== Training : Episode  189000  ===========
# Recent 1000 games win rate :46.468%
#  -- 1000 Games WIN : 421 DRAW : 94 LOSS : 485
# Total win rate : 46.619%
#  -- TOTAL Games WIN : 80121 DRAW : 17137 LOSS : 91742
# ========== Training : Episode  190000  ===========
# Recent 1000 games win rate :48.458%
#  -- 1000 Games WIN : 440 DRAW : 92 LOSS : 468
# Total win rate : 46.629%
#  -- TOTAL Games WIN : 80561 DRAW : 17229 LOSS : 92210
# ========== Training : Episode  191000  ===========
# Recent 1000 games win rate :44.824%
#  -- 1000 Games WIN : 407 DRAW : 92 LOSS : 501
# Total win rate : 46.619%
#  -- TOTAL Games WIN : 80968 DRAW : 17321 LOSS : 92711
# ========== Training : Episode  192000  ===========
# Recent 1000 games win rate :46.128%
#  -- 1000 Games WIN : 417 DRAW : 96 LOSS : 487
# Total win rate : 46.617%
#  -- TOTAL Games WIN : 81385 DRAW : 17417 LOSS : 93198
# ========== Training : Episode  193000  ===========
# Recent 1000 games win rate :45.967%
#  -- 1000 Games WIN : 416 DRAW : 95 LOSS : 489
# Total win rate : 46.613%
#  -- TOTAL Games WIN : 81801 DRAW : 17512 LOSS : 93687
# ========== Training : Episode  194000  ===========
# Recent 1000 games win rate :44.083%
#  -- 1000 Games WIN : 406 DRAW : 79 LOSS : 515
# Total win rate : 46.600%
#  -- TOTAL Games WIN : 82207 DRAW : 17591 LOSS : 94202
# ========== Training : Episode  195000  ===========
# Recent 1000 games win rate :46.689%
#  -- 1000 Games WIN : 423 DRAW : 94 LOSS : 483
# Total win rate : 46.601%
#  -- TOTAL Games WIN : 82630 DRAW : 17685 LOSS : 94685
# ========== Training : Episode  196000  ===========
# Recent 1000 games win rate :43.908%
#  -- 1000 Games WIN : 400 DRAW : 89 LOSS : 511
# Total win rate : 46.587%
#  -- TOTAL Games WIN : 83030 DRAW : 17774 LOSS : 95196
# ========== Training : Episode  197000  ===========
# Recent 1000 games win rate :46.834%
#  -- 1000 Games WIN : 429 DRAW : 84 LOSS : 487
# Total win rate : 46.588%
#  -- TOTAL Games WIN : 83459 DRAW : 17858 LOSS : 95683
# ========== Training : Episode  198000  ===========
# Recent 1000 games win rate :47.415%
#  -- 1000 Games WIN : 431 DRAW : 91 LOSS : 478
# Total win rate : 46.592%
#  -- TOTAL Games WIN : 83890 DRAW : 17949 LOSS : 96161
# ========== Training : Episode  199000  ===========
# Recent 1000 games win rate :47.129%
#  -- 1000 Games WIN : 435 DRAW : 77 LOSS : 488
# Total win rate : 46.595%
#  -- TOTAL Games WIN : 84325 DRAW : 18026 LOSS : 96649
# ========== Training : Episode  200000  ===========
# Recent 1000 games win rate :45.695%
#  -- 1000 Games WIN : 414 DRAW : 94 LOSS : 492
# Total win rate : 46.591%
#  -- TOTAL Games WIN : 84739 DRAW : 18120 LOSS : 97141
# ========== Training : Episode  201000  ===========
# Recent 1000 games win rate :47.965%
#  -- 1000 Games WIN : 436 DRAW : 91 LOSS : 473
# Total win rate : 46.597%
#  -- TOTAL Games WIN : 85175 DRAW : 18211 LOSS : 97614
# ========== Training : Episode  202000  ===========
# Recent 1000 games win rate :47.176%
#  -- 1000 Games WIN : 426 DRAW : 97 LOSS : 477
# Total win rate : 46.600%
#  -- TOTAL Games WIN : 85601 DRAW : 18308 LOSS : 98091
# ========== Training : Episode  203000  ===========
# Recent 1000 games win rate :47.149%
#  -- 1000 Games WIN : 430 DRAW : 88 LOSS : 482
# Total win rate : 46.603%
#  -- TOTAL Games WIN : 86031 DRAW : 18396 LOSS : 98573
# ========== Training : Episode  204000  ===========
# Recent 1000 games win rate :45.302%
#  -- 1000 Games WIN : 405 DRAW : 106 LOSS : 489
# Total win rate : 46.597%
#  -- TOTAL Games WIN : 86436 DRAW : 18502 LOSS : 99062
# ========== Training : Episode  205000  ===========
# Recent 1000 games win rate :50.388%
#  -- 1000 Games WIN : 455 DRAW : 97 LOSS : 448
# Total win rate : 46.615%
#  -- TOTAL Games WIN : 86891 DRAW : 18599 LOSS : 99510
# ========== Training : Episode  206000  ===========
# Recent 1000 games win rate :44.641%
#  -- 1000 Games WIN : 404 DRAW : 95 LOSS : 501
# Total win rate : 46.606%
#  -- TOTAL Games WIN : 87295 DRAW : 18694 LOSS : 100011
# ========== Training : Episode  207000  ===========
# Recent 1000 games win rate :48.622%
#  -- 1000 Games WIN : 441 DRAW : 93 LOSS : 466
# Total win rate : 46.615%
#  -- TOTAL Games WIN : 87736 DRAW : 18787 LOSS : 100477
# ========== Training : Episode  208000  ===========
# Recent 1000 games win rate :45.445%
#  -- 1000 Games WIN : 419 DRAW : 78 LOSS : 503
# Total win rate : 46.610%
#  -- TOTAL Games WIN : 88155 DRAW : 18865 LOSS : 100980
# ========== Training : Episode  209000  ===========
# Recent 1000 games win rate :46.264%
#  -- 1000 Games WIN : 421 DRAW : 90 LOSS : 489
# Total win rate : 46.608%
#  -- TOTAL Games WIN : 88576 DRAW : 18955 LOSS : 101469
# ========== Training : Episode  210000  ===========
# Recent 1000 games win rate :48.475%
#  -- 1000 Games WIN : 445 DRAW : 82 LOSS : 473
# Total win rate : 46.617%
#  -- TOTAL Games WIN : 89021 DRAW : 19037 LOSS : 101942
# ========== Training : Episode  211000  ===========
# Recent 1000 games win rate :47.174%
#  -- 1000 Games WIN : 434 DRAW : 80 LOSS : 486
# Total win rate : 46.620%
#  -- TOTAL Games WIN : 89455 DRAW : 19117 LOSS : 102428
# ========== Training : Episode  212000  ===========
# Recent 1000 games win rate :46.674%
#  -- 1000 Games WIN : 421 DRAW : 98 LOSS : 481
# Total win rate : 46.620%
#  -- TOTAL Games WIN : 89876 DRAW : 19215 LOSS : 102909
# ========== Training : Episode  213000  ===========
# Recent 1000 games win rate :44.839%
#  -- 1000 Games WIN : 417 DRAW : 70 LOSS : 513
# Total win rate : 46.611%
#  -- TOTAL Games WIN : 90293 DRAW : 19285 LOSS : 103422
# ========== Training : Episode  214000  ===========
# Recent 1000 games win rate :45.952%
#  -- 1000 Games WIN : 420 DRAW : 86 LOSS : 494
# Total win rate : 46.608%
#  -- TOTAL Games WIN : 90713 DRAW : 19371 LOSS : 103916
# ========== Training : Episode  215000  ===========
# Recent 1000 games win rate :43.951%
#  -- 1000 Games WIN : 396 DRAW : 99 LOSS : 505
# Total win rate : 46.596%
#  -- TOTAL Games WIN : 91109 DRAW : 19470 LOSS : 104421
# ========== Training : Episode  216000  ===========
# Recent 1000 games win rate :46.205%
#  -- 1000 Games WIN : 420 DRAW : 91 LOSS : 489
# Total win rate : 46.594%
#  -- TOTAL Games WIN : 91529 DRAW : 19561 LOSS : 104910
# ========== Training : Episode  217000  ===========
# Recent 1000 games win rate :48.578%
#  -- 1000 Games WIN : 444 DRAW : 86 LOSS : 470
# Total win rate : 46.603%
#  -- TOTAL Games WIN : 91973 DRAW : 19647 LOSS : 105380
# ========== Training : Episode  218000  ===========
# Recent 1000 games win rate :47.630%
#  -- 1000 Games WIN : 432 DRAW : 93 LOSS : 475
# Total win rate : 46.608%
#  -- TOTAL Games WIN : 92405 DRAW : 19740 LOSS : 105855
# ========== Training : Episode  219000  ===========
# Recent 1000 games win rate :42.934%
#  -- 1000 Games WIN : 398 DRAW : 73 LOSS : 529
# Total win rate : 46.591%
#  -- TOTAL Games WIN : 92803 DRAW : 19813 LOSS : 106384
# ========== Training : Episode  220000  ===========
# Recent 1000 games win rate :46.307%
#  -- 1000 Games WIN : 420 DRAW : 93 LOSS : 487
# Total win rate : 46.590%
#  -- TOTAL Games WIN : 93223 DRAW : 19906 LOSS : 106871
# ========== Training : Episode  221000  ===========
# Recent 1000 games win rate :45.316%
#  -- 1000 Games WIN : 416 DRAW : 82 LOSS : 502
# Total win rate : 46.584%
#  -- TOTAL Games WIN : 93639 DRAW : 19988 LOSS : 107373
# ========== Training : Episode  222000  ===========
# Recent 1000 games win rate :43.384%
#  -- 1000 Games WIN : 400 DRAW : 78 LOSS : 522
# Total win rate : 46.569%
#  -- TOTAL Games WIN : 94039 DRAW : 20066 LOSS : 107895
# ========== Training : Episode  223000  ===========
# Recent 1000 games win rate :46.957%
#  -- 1000 Games WIN : 432 DRAW : 80 LOSS : 488
# Total win rate : 46.571%
#  -- TOTAL Games WIN : 94471 DRAW : 20146 LOSS : 108383
# ========== Training : Episode  224000  ===========
# Recent 1000 games win rate :48.156%
#  -- 1000 Games WIN : 444 DRAW : 78 LOSS : 478
# Total win rate : 46.578%
#  -- TOTAL Games WIN : 94915 DRAW : 20224 LOSS : 108861
# ========== Training : Episode  225000  ===========
# Recent 1000 games win rate :49.109%
#  -- 1000 Games WIN : 441 DRAW : 102 LOSS : 457
# Total win rate : 46.589%
#  -- TOTAL Games WIN : 95356 DRAW : 20326 LOSS : 109318
# ========== Training : Episode  226000  ===========
# Recent 1000 games win rate :44.057%
#  -- 1000 Games WIN : 404 DRAW : 83 LOSS : 513
# Total win rate : 46.578%
#  -- TOTAL Games WIN : 95760 DRAW : 20409 LOSS : 109831
# ========== Training : Episode  227000  ===========
# Recent 1000 games win rate :45.768%
#  -- 1000 Games WIN : 411 DRAW : 102 LOSS : 487
# Total win rate : 46.574%
#  -- TOTAL Games WIN : 96171 DRAW : 20511 LOSS : 110318
# ========== Training : Episode  228000  ===========
# Recent 1000 games win rate
# Total win rate : 46.631%
#  -- TOTAL Games WIN : 419954 DRAW : 89411 LOSS : 480635
# ========== Training : Episode  991000  ===========
# Recent 1000 games win rate :45.526%
#  -- 1000 Games WIN : 407 DRAW : 106 LOSS : 487
# Total win rate : 46.630%
#  -- TOTAL Games WIN : 420361 DRAW : 89517 LOSS : 481122
# ========== Training : Episode  992000  ===========
# Recent 1000 games win rate :47.874%
#  -- 1000 Games WIN : 439 DRAW : 83 LOSS : 478
# Total win rate : 46.631%
#  -- TOTAL Games WIN : 420800 DRAW : 89600 LOSS : 481600
# ========== Training : Episode  993000  ===========
# Recent 1000 games win rate :47.008%
#  -- 1000 Games WIN : 432 DRAW : 81 LOSS : 487
# Total win rate : 46.632%
#  -- TOTAL Games WIN : 421232 DRAW : 89681 LOSS : 482087
# ========== Training : Episode  994000  ===========
# Recent 1000 games win rate :47.116%
#  -- 1000 Games WIN : 433 DRAW : 81 LOSS : 486
# Total win rate : 46.632%
#  -- TOTAL Games WIN : 421665 DRAW : 89762 LOSS : 482573
# ========== Training : Episode  995000  ===========
# Recent 1000 games win rate :43.730%
#  -- 1000 Games WIN : 401 DRAW : 83 LOSS : 516
# Total win rate : 46.629%
#  -- TOTAL Games WIN : 422066 DRAW : 89845 LOSS : 483089
# ========== Training : Episode  996000  ===========
# Recent 1000 games win rate :48.043%
#  -- 1000 Games WIN : 442 DRAW : 80 LOSS : 478
# Total win rate : 46.631%
#  -- TOTAL Games WIN : 422508 DRAW : 89925 LOSS : 483567
# ========== Training : Episode  997000  ===========
# Recent 1000 games win rate :42.492%
#  -- 1000 Games WIN : 382 DRAW : 101 LOSS : 517
# Total win rate : 46.626%
#  -- TOTAL Games WIN : 422890 DRAW : 90026 LOSS : 484084
# ========== Training : Episode  998000  ===========
# Recent 1000 games win rate :47.305%
#  -- 1000 Games WIN : 430 DRAW : 91 LOSS : 479
# Total win rate : 46.627%
#  -- TOTAL Games WIN : 423320 DRAW : 90117 LOSS : 484563
# ========== Training : Episode  999000  ===========
# Recent 1000 games win rate :46.196%
#  -- 1000 Games WIN : 425 DRAW : 80 LOSS : 495
# Total win rate : 46.627%
#  -- TOTAL Games WIN : 423745 DRAW : 90197 LOSS : 485058
# ========== Training : Episode  1000000  ===========
# Recent 1000 games win rate :48.337%
#  -- 1000 Games WIN : 436 DRAW : 98 LOSS : 466
# Total win rate : 46.628%
#  -- TOTAL Games WIN : 424181 DRAW : 90295 LOSS : 485524

# %%
def AdvancedPlayGame(money=10000, bet=10, win=20, draw=10, lose=0, it=1000):
    money_trace = []
    w, d, l = 0, 0, 0
    adv_agent.new_game()
    
    for i in range(it):    
        money -= bet
        episode = adv_mc_es.generate_episode(dealer, adv_agent, adv_deck)
        
        if episode[-1][-1] == 1:
            w += 1
            money += win
        elif episode[-1][-1] == 0:
            d += 1
            money += draw
        else:
            l += 1
            money += lose
            
        money_trace.append(money)
    
    return money_trace, w, d, l

# %%
money_trace, win, draw, lose = AdvancedPlayGame()

# %%
############### 코드 작성 ##############################
print("Total win rate : {:.3f}%".format(win / (win + lose) * 100))
print(" -- TOTAL Games WIN :", win, "DRAW :", draw, "LOSS :", lose)
########################################################
# Out:
# Total win rate : 51.140%
#  -- TOTAL Games WIN : 471 DRAW : 79 LOSS : 450

# %%
############### 코드 작성 ##############################
plt.figure(figsize=(12, 7))

plt.plot(money_trace)
plt.xlabel('Games')
plt.ylabel('Money')
plt.show()
########################################################

# %% [markdown]
# ---
# ### 참고자료
# [1] Reinforcement Learning - An Introduction (Richard S. Sutton, Andreow G. Barto), 2nd edition, p.120-124 https://web.stanford.edu/class/psych209/Readings/SuttonBartoIPRLBook2ndEd.pdf <br>
# [2] matplotlib.pyplot.plot Documentation, https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html <br>
# [3] matplotlib.pyplot.plot Examples https://matplotlib.org/tutorials/introductory/pyplot.html
