# %%
import os
import pandas as pd
import numpy as np

import json
import distutils.dir_util
import io
os.environ['KMP_DUPLICATE_LIB_OK']='True'

from tqdm.notebook import tqdm
from collections import Counter

# %%
path = '../../data/'
tqdm.pandas()

# %%
print("All data in path")
print(os.listdir(path))
# Out:
# All data in path
# ['train.json', 'test.json', 'onehot_matrix.csv', 'new_date', 'genre_all.json', 'song_meta.json', '.ipynb_checkpoints', 'genre_gn_all.json', 'val.json', 'train_genre_count.csv']

# %% [markdown]
# # Basic Module

# %%
def write_json(data, fname):
    def _conv(o):
        if isinstance(o, np.int64) or isinstance(o, np.int32):
            return int(o)
        raise TypeError

    parent = os.path.dirname(fname)
    distutils.dir_util.mkpath("./arena_data/" + parent)
    with io.open("./arena_data/" + fname, "w", encoding="utf8") as f:
        json_str = json.dumps(data, ensure_ascii=False, default=_conv)
        f.write(json_str)
        print('file save seuccess')

# %%
song_meta = pd.read_json(path+'song_meta.json')
train = pd.read_json(path+'train.json')
val = pd.read_json(path+'val.json')

# %%
n_train = len(train)
n_val = len(val)

train['istrain'] = 1
val['istrain'] = 0

playlist = pd.concat([train, val], ignore_index=True)

song_list = [song for songs in playlist.songs for song in songs]
song_counter = dict(Counter(song_list))

tag_list = [tag for tags in playlist.tags for tag in tags]
tag_counter = dict(Counter(tag_list))

# %%
song_to_sid = dict()
sid_to_song = dict()

for i, s in enumerate(song_counter):
    song_to_sid[s] = i
    sid_to_song[i] = s

tag_to_tid = dict()
tid_to_tag = dict()

for i, t in enumerate(tag_counter):
    tag_to_tid[t] = i
    tid_to_tag[i] = t

# %%
id_to_nid = dict(zip(playlist['id'], range(n_train+n_val)))
nid_to_id = dict(zip(range(n_train+n_val) , playlist['id']))

# %%
n_song = len(song_counter)
n_tag = len(tag_counter)

train['sid_list'] = train['songs'].progress_apply(lambda x: [song_to_sid[s] for s in x])
train['tid_list'] = train['tags'].progress_apply(lambda x: [tag_to_tid[t] for t in x])
train['nid'] = train['id'].progress_apply(lambda x: id_to_nid[x])
val['sid_list'] = val['songs'].progress_apply(lambda x: [song_to_sid[s] for s in x])
val['tid_list'] = val['tags'].progress_apply(lambda x: [tag_to_tid[t] for t in x])
val['nid'] = val['id'].progress_apply(lambda x: id_to_nid[x])

train['num_songs'] = train['sid_list'].map(len)
train['num_tags'] = train['tid_list'].map(len)
val['num_songs'] = val['sid_list'].map(len)
val['num_tags'] = val['tid_list'].map(len)
# Out:
#   0%|          | 0/115071 [00:00<?, ?it/s]
#   0%|          | 0/115071 [00:00<?, ?it/s]
#   0%|          | 0/115071 [00:00<?, ?it/s]
#   0%|          | 0/23015 [00:00<?, ?it/s]
#   0%|          | 0/23015 [00:00<?, ?it/s]
#   0%|          | 0/23015 [00:00<?, ?it/s]

# %%
train_use = train[['nid', 'sid_list', 'tid_list', 'istrain', 'num_songs', 'num_tags']]
val_use = val[['nid', 'sid_list', 'tid_list', 'istrain', 'num_songs', 'num_tags']]
train_use = train_use.set_index('nid')
val_use = val_use.set_index('nid')

# %%
use_data = pd.concat([train_use, val_use])

# %% [markdown]
# # Make Sparse Matrix

# %%
from scipy.sparse import csr_matrix

def make_sparse(data):
    row = np.repeat(range(n_train+n_val), data['num_songs'])
    col = [sid for songs in data['sid_list'] for sid in songs]
    # (0, 1) --> 0번 playlist는 1번 노래를 갖고 있는 것
    dat = np.repeat(1, data['num_songs'].sum())
    songs_sparse = csr_matrix((dat, (row, col)), shape=(n_train+n_val, n_song))
    
    row = np.repeat(range(n_train+n_val), data['num_tags'])
    col = [tid for tags in data['tid_list'] for tid in tags]
    dat = np.repeat(1, data['num_tags'].sum())
    tags_sparse = csr_matrix((dat, (row, col)), shape=(n_train+n_val, n_tag))
    
    return songs_sparse, tags_sparse

# %%
song_sparse, tag_sparse = make_sparse(use_data)

# %%
from implicit.evaluation import  *
from implicit.als import AlternatingLeastSquares as ALS
from implicit.bpr import BayesianPersonalizedRanking as BPR

# %%
bpr_model_item = BPR(factors=100)
bpr_model_item.fit(song_sparse.T)

bpr_model_tag = BPR(factors=100)
bpr_model_tag.fit(tag_sparse.T)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
val_song_sparse = song_sparse[n_train:]
val_tag_sparse = tag_sparse[n_train:]

# %%
train_song_sparse = song_sparse[:n_train]
train_tag_sparse = tag_sparse[n_train:]

# %%
song_ret = []

for s in tqdm(range(val_song_sparse.shape[0])):
    song_recom = bpr_model_item.recommend(s, train_song_sparse, N=100)
    song_recom = [sid_to_song[x[0]] for x in song_recom]
    song_ret.append(song_recom)
# Out:
#   0%|          | 0/23015 [00:00<?, ?it/s]

# %%
tag_ret = []

for s in tqdm(range(val_tag_sparse.shape[0])):
    tag_recom = bpr_model_tag.recommend(s, train_tag_sparse, N=100)
    tag_recom = [tid_to_tag[x[0]] for x in tag_recom if x[0] in tid_to_tag]
    tag_ret.append(tag_recom)
# Out:
#   0%|          | 0/23015 [00:00<?, ?it/s]

# %%
answer = []

for _id, rec, rec_tag in zip(val.id.tolist(), song_ret, tag_ret):
    answer.append({
        "id":_id,
        "songs":rec[:100],
        "tags":rec_tag[:10]
    })

# %%
write_json(answer, "own_result/mf/results.json")
# Out:
# file save seuccess

# %%
song_meta.loc[val.loc[0, 'songs']]
# Out:
#                                   song_gn_dtl_gnr_basket  issue_date  \
# 373313                  [GN2207, GN1501, GN1506, GN1509]    20150101
# 151080                  [GN2207, GN1509, GN1501, GN1506]    20150312
# 275346                                  [GN1301, GN1302]    20150814
# 696876                                  [GN1301, GN1302]    20151006
# 165237          [GN2207, GN1501, GN0901, GN1509, GN1506]    20151030
# 525935          [GN2207, GN0901, GN1509, GN1501, GN1506]    20160212
# 457812          [GN2207, GN0901, GN1509, GN1501, GN1506]    20171110
# 371709                  [GN2207, GN1509, GN1501, GN1506]    20171103
# 170292                  [GN1503, GN1501, GN0908, GN0901]    20190522
# 438915                          [GN1503, GN1501, GN1509]    20000513
# 162569                                  [GN1503, GN1501]    20081118
# 161136                                  [GN1503, GN1501]    20081118
# 310892                          [GN1501, GN1506, GN1509]    20110614
# 608704          [GN2207, GN0901, GN1509, GN1501, GN1506]    20110923
# 295701          [GN2207, GN1501, GN0901, GN1509, GN1506]    20120925
# 127698          [GN1501, GN1509, GN1506, GN0902, GN1001]    20121030
# 269427          [GN2207, GN1501, GN0901, GN1509, GN1506]    20131202
# 592526          [GN2207, GN1501, GN0901, GN1509, GN1506]    20131202
# 110696                                  [GN1503, GN1501]    20140626
# 368214  [GN1509, GN2207, GN1003, GN1001, GN1501, GN1506]    20141103
# 24386                                   [GN1503, GN1501]    20150309
# 104455                  [GN2207, GN1501, GN1506, GN1509]    20150101
# 61612           [GN2207, GN1501, GN0901, GN1509, GN1506]    19950101
# 151421          [GN2207, GN0901, GN1509, GN1501, GN1506]    19950101
# 416023                          [GN1501, GN1506, GN1509]    19960703
# 320447                  [GN2207, GN1509, GN1501, GN1506]    20181005
# 19606                   [GN2207, GN1501, GN1506, GN1509]    20021119
#
#                                                album_name  album_id  \
# 373313  Walt Disney Records The Legacy Collection: Pin...   2308104
# 151080           겨울왕국 열기 OST (Making Today A Perfect Day)   2308739
# 275346                                     Friend Like Me   2334904
# 696876  Ev&#39;rybody Wants To Be A Cat (From &#34;The...   2643514
# 165237                            We Love Disney (Deluxe)   2647713
# 525935                         영화 주토피아 OST (Zootopia OST)   2666420
# 457812          Coco (Original Motion Picture Soundtrack)  10105939
# 371709  Olaf&#39;s Frozen Adventure (Original Soundtrack)  10108314
# 170292       Aladdin (Original Motion Picture Soundtrack)  10288448
# 438915                                      쿠스코? 쿠스코! OST     41158
# 162569                                             볼트 OST    477452
# 161136                                             볼트 OST    477452
# 310892                                            카 2 OST   1317283
# 608704                              Best of The Lion King   2117568
# 295701                           Frankenweenie Unleashed!   2151188
# 127698                                         주먹왕 랄프 OST   2165582
# 269427                          겨울왕국 OST (Deluxe Edition)   2219433
# 592526                                           겨울왕국 OST   2225293
# 110696                                        Still I Fly    149542
# 368214    Big Hero 6 (Original Motion Picture Soundtrack)   2288829
# 24386     Cinderella (Original Motion Picture Soundtrack)   2307850
# 104455  Walt Disney Records The Legacy Collection: Pin...   2308104
# 61612                                            인어공주 OST     27363
# 151421                                           인어공주 OST     27363
# 416023                                        노틀담의 꼽추 OST     27548
# 320447        Tarzan (Original Motion Picture Soundtrack)     27827
# 19606                                             보물성 OST     29511
#
#                         artist_id_basket  \
# 373313                          [353277]
# 151080         [232538, 746208, 2758138]
# 275346                          [181769]
# 696876                          [871816]
# 165237                          [742133]
# 525935                           [10379]
# 457812                          [553325]
# 371709  [746208, 232538, 746216, 407770]
# 170292                           [27242]
# 438915                           [28192]
# 162569                          [254676]
# 161136                          [327767]
# 310892                          [105176]
# 608704                   [666718, 33674]
# 295701                           [35750]
# 127698                          [177834]
# 269427          [746208, 746210, 746211]
# 592526                          [232538]
# 110696                          [698241]
# 368214                          [169595]
# 24386                           [234970]
# 104455                   [29921, 560361]
# 61612                            [29233]
# 151421                           [51017]
# 416023                          [103514]
# 320447                            [3382]
# 19606                           [710763]
#
#                                                 song_name  \
# 373313                            I&#39;ve Got No Strings
# 151080                         Making Today A Perfect Day
# 275346            Friend Like Me (From &#34;Aladdin&#34;)
# 696876  Ev’rybody Wants To Be A Cat (From &#34;The Ari...
# 165237     Colors Of The Wind (From &#34;Pocahontas&#34;)
# 525935  Try Everything (From &#34;Zootopia&#34;/Soundt...
# 457812  Remember Me (D&#250;o) (From &#34;Coco&#34;/So...
# 371709  When We&#39;re Together (From &#34;Olaf&#39;s ...
# 170292  Arabian Nights (2019) (From &#34;Aladdin&#34;/...
# 438915                             My Funny Friend And Me
# 162569          I Thought I Lost You (With John Travolta)
# 161136                                Barking At The Moon
# 310892  You Might Think (From &#34;Cars 2&#34;/Soundtr...
# 608704  Circle of Life (From &#34;The Lion King&#34;/ ...
# 295701                                       Strange Love
# 127698                                  Shut Up And Drive
# 269427                    Do You Want To Build A Snowman?
# 592526                                          Let It Go
# 110696                                        Still I Fly
# 368214   Immortals (From &#34;Big Hero 6&#34;/Soundtrack)
# 24386   Bibbidi-Bobbidi-Boo (The Magic Song) (From &#3...
# 104455                          When You Wish Upon a Star
# 61612   Part of Your World (From &#34;The Little Merma...
# 151421  Under the Sea (From &#34;The Little Mermaid&#3...
# 416023                                            Someday
# 320447  You&#39;ll Be In My Heart (From &#34;Tarzan&#3...
# 19606                        I`m Still Here (Jim`s Theme)
#
#               song_gn_gnr_basket  \
# 373313          [GN1500, GN2200]
# 151080          [GN1500, GN2200]
# 275346                  [GN1300]
# 696876                  [GN1300]
# 165237  [GN1500, GN0900, GN2200]
# 525935  [GN1500, GN0900, GN2200]
# 457812  [GN1500, GN0900, GN2200]
# 371709          [GN1500, GN2200]
# 170292          [GN1500, GN0900]
# 438915                  [GN1500]
# 162569                  [GN1500]
# 161136                  [GN1500]
# 310892                  [GN1500]
# 608704  [GN1500, GN0900, GN2200]
# 295701  [GN1500, GN0900, GN2200]
# 127698  [GN1500, GN0900, GN1000]
# 269427  [GN1500, GN0900, GN2200]
# 592526  [GN1500, GN0900, GN2200]
# 110696                  [GN1500]
# 368214  [GN1500, GN2200, GN1000]
# 24386                   [GN1500]
# 104455          [GN1500, GN2200]
# 61612   [GN1500, GN0900, GN2200]
# 151421  [GN1500, GN0900, GN2200]
# 416023                  [GN1500]
# 320447          [GN1500, GN2200]
# 19606           [GN1500, GN2200]
#
#                                        artist_name_basket      id
# 373313                                     [Dickie Jones]  373313
# 151080  [Idina Menzel, Kristen Bell, Cast of Frozen Fe...  151080
# 275346                                            [Ne-Yo]  275346
# 696876                                    [Charles Perry]  696876
# 165237                                       [Tori Kelly]  165237
# 525935                                          [Shakira]  525935
# 457812                                           [Miguel]  457812
# 371709  [Kristen Bell, Idina Menzel, Josh Gad, Jonatha...  371709
# 170292                                       [Will Smith]  170292
# 438915                                            [Sting]  438915
# 162569                                      [Miley Cyrus]  162569
# 161136                                      [Jenny Lewis]  161136
# 310892                                           [Weezer]  310892
# 608704                           [Carmen Twillie, Lebo M]  608704
# 295701                                          [Karen O]  295701
# 127698                                          [Rihanna]  127698
# 269427       [Kristen Bell, Agatha Lee Monn, Katie Lopez]  269427
# 592526                                     [Idina Menzel]  592526
# 110696                                      [Spencer Lee]  110696
# 368214                                     [Fall Out Boy]  368214
# 24386                              [Helena Bonham Carter]   24386
# 104455              [Cliff Edwards, Disney Studio Chorus]  104455
# 61612                                       [Jodi Benson]   61612
# 151421                                 [Samuel E. Wright]  151421
# 416023                                        [All-4-One]  416023
# 320447                                     [Phil Collins]  320447
# 19606                                      [John Rzeznik]   19606

# %%
song_meta.loc[answer[1]['songs']]
# Out:
#                           song_gn_dtl_gnr_basket  issue_date  \
# 86502   [GN0508, GN0501, GN0601, GN0503, GN0605]    20080624
# 380361                  [GN0601, GN1501, GN1504]    20141031
# 136857                                  [GN0101]    20091027
# 302043                          [GN0804, GN0801]    20070216
# 206440                          [GN0105, GN0101]    20120420
# ...                                          ...         ...
# 27044           [GN0501, GN0502, GN0801, GN0509]    20140512
# 610473                          [GN0104, GN0101]    20090911
# 157722  [GN0508, GN0501, GN0601, GN0503, GN0605]    20080325
# 39357                                   [GN0101]    20010411
# 277247                                  [GN1501]    20070123
#
#                        album_name  album_id artist_id_basket  \
# 86502               R.A.I.N.B.O.W    386406         [184730]
# 380361       가족끼리 왜 이래 OST Part.1   2288486         [232828]
# 136857  환타스틱 프렌즈 (이승환 20주년 기념 앨범)    704551   [7523, 439041]
# 302043         The Light Of Songs    345486           [2800]
# 206440                        돌멩이   2114406         [663911]
# ...                           ...       ...              ...
# 27044                       작은 위로   2255402         [749751]
# 610473                    Blossom    661052         [182200]
# 157722               New Standard    374703         [108707]
# 39357                     윤상 Best    317423             [38]
# 277247              꽃피는 봄이 오면 OST    341467         [204786]
#
#                             song_name song_gn_gnr_basket  \
# 86502                      Love Today   [GN0500, GN0600]
# 380361                        내가 말했잖아   [GN0600, GN1500]
# 136857                       내가 바라는 나           [GN0100]
# 302043                          보이나요?           [GN0800]
# 206440                            돌멩이           [GN0100]
# ...                               ...                ...
# 27044                           작은 위로   [GN0500, GN0800]
# 610473                          봄이 오면           [GN0100]
# 157722          New Hippie Generation   [GN0500, GN0600]
# 39357                             달리기           [GN0100]
# 277247  하얀 민들레 (Acoustic Guitar Ver.)           [GN1500]
#
#           artist_name_basket      id
# 86502                   [타루]   86502
# 380361                  [요조]  380361
# 136857     [유희열, 김종완 (NELL)]  136857
# 302043                [루시드폴]  302043
# 206440              [마시따 밴드]  206440
# ...                      ...     ...
# 27044                  [이매진]   27044
# 610473                  [허민]  610473
# 157722  [페퍼톤스 (Peppertones)]  157722
# 39357                   [윤상]   39357
# 277247                 [이하나]  277247
#
# [100 rows x 9 columns]
